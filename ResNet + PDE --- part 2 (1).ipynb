# %%
import numpy as np
import random

import torch
import torch.nn as nn
import torch.nn.functional as func
import torch.optim as optim

from matplotlib import pyplot as plt

from numpy import exp,arange
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

# %%
# ==========
# helping methods
# ==========

# generate a list from lower and upper bound
def gen_list(p0, pn, delta, dig=5):
    ret = []
    i = p0
    while i < pn:
        ret.append(float(i))
        i += delta
        i = round(i, dig)
    return ret

# padding and zero padding
def padding(origin, a_list, b_list):
    return np.hstack((a_list, origin, b_list))

def zero_padding(origin, num):
    zero_list = [0 for i in range(num)]
    return padding(origin, zero_list, zero_list)

# trainning pairs
def gen_pair(u, x, t, length=3, num=1000):
    pairs = []
    for i in range(num):
        r = random.randint(0, t-2)
        current_t = u[r]
        next_t = u[r+1]
        p = random.randint(length, x-1-length)
        train = current_t[p-length:p+length+1]
        solu = next_t[p]
        pair = {'input': train, 'solu': solu}
        pairs.append(pair)
    return pairs

# %%
# the analytical representation of exact solution
def heat_equ_analytical_solu(x, t):
    return np.sin(np.pi * x) * np.exp(-np.power(np.pi, 2) * t)

# %%
# restnet
class ResNet(nn.Module):
    def __init__(self, i, h, o):
        super(ResNet, self).__init__()
        self.linear1 = nn.Linear(i, h)
        self.relu1 = nn.ReLU()
        self.linear2 = nn.Linear(h, o)
        self.relu2 = nn.ReLU()
        
    def forward(self, x):
        out = self.linear1(x)
        out = self.relu1(out)
        out = self.linear2(out)
        out = self.relu2(out)
        return out + torch.mean(x)

    def load_model(self, save_path):
        self.load_state_dict(torch.load(save_path))

    def save_model(self, save_path):
        torch.save(self.state_dict(), save_path)

# %%
def calc_next_time(current, model, length=3):
    ret = []
    p = np.hstack(([0 for i in range(length)], current, [0 for i in range(length)])).tolist()
    for index in range(len(current)):
        i = index + 3
        seg = p[i-length:i+length+1]
        tensor_seg = torch.FloatTensor(seg)
        out = model(tensor_seg)
        ret.append(out.item())
    return ret

# %% [markdown]
# ## $\Delta x=\frac{1}{20}$

# %%
x_1 = arange(0, 2 * np.pi, 1/20)
t_1 = arange(0, 2 * np.pi, 1/20)
X_1,T_1 = meshgrid(x_1, t_1) # grid of point
Z_1 = heat_equ_analytical_solu(X_1, T_1) # evaluation of the function on the grid

# %%
padding_1 = []
for z in Z_1:
    p = np.hstack(([0,0,0], z, [0,0,0]))
    padding_1.append(p.tolist())

# %%
model_1 = ResNet(7, 6, 1)
optimizer_1 = optim.Adam(model_1.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
criterion_1 = nn.MSELoss()
model_1.train()
# Out:
# ResNet(
#   (linear1): Linear(in_features=7, out_features=6, bias=True)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=6, out_features=1, bias=True)
#   (relu2): ReLU()
# )

# %%
model_1.load_model("model delta x=1 20")

# %%
prediction_1 = []
prediction_1.append(torch.FloatTensor(Z_1[0]).tolist())
for i in range(len(Z_1)-1):
    prediction_1.append(calc_next_time(Z_1[i], model_1))
    print("time", i, "is done", '", an example is:"', prediction_1[i+1][0])
# Out:
# time 0 is done ", an example is:" 0.1313488483428955
# time 1 is done ", an example is:" 0.08018821477890015
# time 2 is done ", an example is:" 0.04895474761724472
# time 3 is done ", an example is:" 0.029886778444051743
# time 4 is done ", an example is:" 0.018245818093419075
# time 5 is done ", an example is:" 0.01113903522491455
# time 6 is done ", an example is:" 0.006800359580665827
# time 7 is done ", an example is:" 0.004151606000959873
# time 8 is done ", an example is:" 0.0025345473550260067
# time 9 is done ", an example is:" 0.0015473359962925315
# time 10 is done ", an example is:" 0.0009446456097066402
# time 11 is done ", an example is:" 0.0005767042748630047
# time 12 is done ", an example is:" 0.00035207680775783956
# time 13 is done ", an example is:" 0.00021494222164619714
# time 14 is done ", an example is:" 0.0001312217937083915
# time 15 is done ", an example is:" 8.011063619051129e-05
# time 16 is done ", an example is:" 4.8907390009844676e-05
# time 17 is done ", an example is:" 2.9857865229132585e-05
# time 18 is done ", an example is:" 1.8228167391498573e-05
# time 19 is done ", an example is:" 1.1128261576232035e-05
# time 20 is done ", an example is:" 6.793780812586192e-06
# time 21 is done ", an example is:" 4.147590061620576e-06
# time 22 is done ", an example is:" 2.5320955501229037e-06
# time 23 is done ", an example is:" 1.5458392681466648e-06
# time 24 is done ", an example is:" 9.437318340133061e-07
# time 25 is done ", an example is:" 5.761464194620203e-07
# time 26 is done ", an example is:" 3.51736247239387e-07
# time 27 is done ", an example is:" 2.1473428546414652e-07
# time 28 is done ", an example is:" 1.310948647414989e-07
# time 29 is done ", an example is:" 8.003315343785289e-08
# time 30 is done ", an example is:" 4.886007687332494e-08
# time 31 is done ", an example is:" 2.982898550385471e-08
# time 32 is done ", an example is:" 1.8210537078289235e-08
# time 33 is done ", an example is:" 1.1117495368750951e-08
# time 34 is done ", an example is:" 6.787209905212421e-09
# time 35 is done ", an example is:" 4.143577481130478e-09
# time 36 is done ", an example is:" 2.529646048188283e-09
# time 37 is done ", an example is:" 1.5443438750040173e-09
# time 38 is done ", an example is:" 9.42818934035472e-10
# time 39 is done ", an example is:" 5.755890764014282e-10
# time 40 is done ", an example is:" 3.513959956347179e-10
# time 41 is done ", an example is:" 2.1452657705811617e-10
# time 42 is done ", an example is:" 1.3096804196699452e-10
# time 43 is done ", an example is:" 7.995572953722885e-11
# time 44 is done ", an example is:" 4.8812818370658206e-11
# time 45 is done ", an example is:" 2.980012764330908e-11
# time 46 is done ", an example is:" 1.8192919393200668e-11
# time 47 is done ", an example is:" 1.1106741394650843e-11
# time 48 is done ", an example is:" 6.780643321130375e-12
# time 49 is done ", an example is:" 4.139569763361717e-12
# time 50 is done ", an example is:" 2.527198936230768e-12
# time 51 is done ", an example is:" 1.5428500491077024e-12
# time 52 is done ", an example is:" 9.419069257193824e-13
# time 53 is done ", an example is:" 5.750323177691752e-13
# time 54 is done ", an example is:" 3.510560711485894e-13
# time 55 is done ", an example is:" 2.1431905458235007e-13
# time 56 is done ", an example is:" 1.3084136909775196e-13
# time 57 is done ", an example is:" 7.98783917699622e-14
# time 58 is done ", an example is:" 4.8765597679759076e-14
# time 59 is done ", an example is:" 2.977130057779144e-14
# time 60 is done ", an example is:" 1.8175321274058187e-14
# time 61 is done ", an example is:" 1.1095997777825668e-14
# time 62 is done ", an example is:" 6.774084585777591e-15
# time 63 is done ", an example is:" 4.135565096619184e-15
# time 64 is done ", an example is:" 2.524754494012682e-15
# time 65 is done ", an example is:" 1.5413576067007935e-15
# time 66 is done ", an example is:" 9.409957944008776e-16
# time 67 is done ", an example is:" 5.744760089757917e-16
# time 68 is done ", an example is:" 3.507165064397052e-16
# time 69 is done ", an example is:" 2.1411173109241096e-16
# time 70 is done ", an example is:" 1.3071478616477367e-16
# time 71 is done ", an example is:" 7.980112463042027e-17
# time 72 is done ", an example is:" 4.871842675903362e-17
# time 73 is done ", an example is:" 2.974250315165069e-17
# time 74 is done ", an example is:" 1.815773941117203e-17
# time 75 is done ", an example is:" 1.1085264110143613e-17
# time 76 is done ", an example is:" 6.767531859488293e-18
# time 77 is done ", an example is:" 4.131564914042604e-18
# time 78 is done ", an example is:" 2.5223121224857498e-18
# time 79 is done ", an example is:" 1.5398665036316452e-18
# time 80 is done ", an example is:" 9.400855962876875e-19
# time 81 is done ", an example is:" 5.739203462634061e-19
# time 82 is done ", an example is:" 3.5037721556399975e-19
# time 83 is done ", an example is:" 2.139046283314824e-19
# time 84 is done ", an example is:" 1.305883345475448e-19
# time 85 is done ", an example is:" 7.972392593180223e-20
# time 86 is done ", an example is:" 4.867130078027161e-20
# time 87 is done ", an example is:" 2.971373316371124e-20
# time 88 is done ", an example is:" 1.8140174230864466e-20
# time 89 is done ", an example is:" 1.107454122569142e-20
# time 90 is done ", an example is:" 6.760985778302747e-21
# time 91 is done ", an example is:" 4.12756865263817e-21
# time 92 is done ", an example is:" 2.519872248255861e-21
# time 93 is done ", an example is:" 1.5383771140477487e-21
# time 94 is done ", an example is:" 9.39176141900341e-22
# time 95 is done ", an example is:" 5.733651590344699e-22
# time 96 is done ", an example is:" 3.500383086002649e-22
# time 97 is done ", an example is:" 2.1369769868071526e-22
# time 98 is done ", an example is:" 1.3046200583206819e-22
# time 99 is done ", an example is:" 7.964681118111115e-23
# time 100 is done ", an example is:" 4.862421868368344e-23
# time 101 is done ", an example is:" 2.96849904802041e-23
# time 102 is done ", an example is:" 1.812262621566533e-23
# time 103 is done ", an example is:" 1.1063828627127151e-23
# time 104 is done ", an example is:" 6.75444558497305e-24
# time 105 is done ", an example is:" 4.123575138968797e-24
# time 106 is done ", an example is:" 2.5174346144161865e-24
# time 107 is done ", an example is:" 1.5368888908735868e-24
# time 108 is done ", an example is:" 9.382677094034111e-25
# time 109 is done ", an example is:" 5.728105401198625e-25
# time 110 is done ", an example is:" 3.4969969735366216e-25
# time 111 is done ", an example is:" 2.134909798498696e-25
# time 112 is done ", an example is:" 1.3033582062774516e-25
# time 113 is done ", an example is:" 7.956976791896745e-26
# time 114 is done ", an example is:" 4.857718248243109e-26
# time 115 is done ", an example is:" 2.9656273552019434e-26
# time 116 is done ", an example is:" 1.8105097331920866e-26
# time 117 is done ", an example is:" 1.1053125343876185e-26
# time 118 is done ", an example is:" 6.747911561028668e-27
# time 119 is done ", an example is:" 4.1195864918316524e-27
# time 120 is done ", an example is:" 2.5149994994093823e-27
# time 121 is done ", an example is:" 1.5354021962160362e-27
# time 122 is done ", an example is:" 9.373600224724813e-28
# time 123 is done ", an example is:" 5.72256427348889e-28
# time 124 is done ", an example is:" 3.4936142894415993e-28

# %%
diff_1 = (prediction_1-Z_1).tolist()

# %%
import csv

with open("prediction_1.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(prediction_1)

# %%
import csv

with open("diff_1.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(diff_1)

# %% [markdown]
# ## $\Delta x=\frac{1}{40}$

# %%
x_2 = arange(0, 2 * np.pi, 1/40)
t_2 = arange(0, 2 * np.pi, 1/40)
X_2,T_2 = meshgrid(x_2, t_2) # grid of point
Z_2 = heat_equ_analytical_solu(X_2, T_2) # evaluation of the function on the grid

# %%
padding_2 = []
for z in Z_2:
    p = np.hstack(([0,0,0], z, [0,0,0]))
    padding_2.append(p.tolist())

# %%
model_2 = ResNet(7, 6, 1)
optimizer_2 = optim.Adam(model_2.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
criterion_2 = nn.MSELoss()
model_2.train()
# Out:
# ResNet(
#   (linear1): Linear(in_features=7, out_features=6, bias=True)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=6, out_features=1, bias=True)
#   (relu2): ReLU()
# )

# %%
model_2.load_model("model delta x=1 40")

# %%
prediction_2 = []
prediction_2.append(torch.FloatTensor(Z_2[0]).tolist())
for i in range(len(Z_2)-1):
    prediction_2.append(calc_next_time(Z_2[i], model_2))
    print("time", i, "is done", '", an example is:"', prediction_2[i+1][0])
# Out:
# time 0 is done ", an example is:" 0.06690555810928345
# time 1 is done ", an example is:" 0.05227624252438545
# time 2 is done ", an example is:" 0.04084571450948715
# time 3 is done ", an example is:" 0.03191453963518143
# time 4 is done ", an example is:" 0.02493622712790966
# time 5 is done ", an example is:" 0.019483763724565506
# time 6 is done ", an example is:" 0.015223517082631588
# time 7 is done ", an example is:" 0.011894799768924713
# time 8 is done ", an example is:" 0.009293926879763603
# time 9 is done ", an example is:" 0.007261752150952816
# time 10 is done ", an example is:" 0.005673923995345831
# time 11 is done ", an example is:" 0.004433284979313612
# time 12 is done ", an example is:" 0.0034639197401702404
# time 13 is done ", an example is:" 0.0027065116446465254
# time 14 is done ", an example is:" 0.0021147162187844515
# time 15 is done ", an example is:" 0.0016523200320079923
# time 16 is done ", an example is:" 0.0012910299701616168
# time 17 is done ", an example is:" 0.001008738181553781
# time 18 is done ", an example is:" 0.0007881712517701089
# time 19 is done ", an example is:" 0.0006158326868899167
# time 20 is done ", an example is:" 0.00048117697588168085
# time 21 is done ", an example is:" 0.000375964620616287
# time 22 is done ", an example is:" 0.0002937575918622315
# time 23 is done ", an example is:" 0.00022952565632294863
# time 24 is done ", an example is:" 0.0001793384290067479
# time 25 is done ", an example is:" 0.00014012496103532612
# time 26 is done ", an example is:" 0.00010948575800284743
# time 27 is done ", an example is:" 8.554600935894996e-05
# time 28 is done ", an example is:" 6.684083928121254e-05
# time 29 is done ", an example is:" 5.222567051532678e-05
# time 30 is done ", an example is:" 4.080620055901818e-05
# time 31 is done ", an example is:" 3.18836719088722e-05
# time 32 is done ", an example is:" 2.4912105800467543e-05
# time 33 is done ", an example is:" 1.9464916476863436e-05
# time 34 is done ", an example is:" 1.5208790500764735e-05
# time 35 is done ", an example is:" 1.188329315482406e-05
# time 36 is done ", an example is:" 9.28493682295084e-06
# time 37 is done ", an example is:" 7.2547272793599404e-06
# time 38 is done ", an example is:" 5.668435733241495e-06
# time 39 is done ", an example is:" 4.428996817296138e-06
# time 40 is done ", an example is:" 3.4605686778377276e-06
# time 41 is done ", an example is:" 2.703893642319599e-06
# time 42 is done ", an example is:" 2.11267047234287e-06
# time 43 is done ", an example is:" 1.650721742407768e-06
# time 44 is done ", an example is:" 1.2897810393042164e-06
# time 45 is done ", an example is:" 1.0077623073811992e-06
# time 46 is done ", an example is:" 7.874087941672769e-07
# time 47 is done ", an example is:" 6.152368996481528e-07
# time 48 is done ", an example is:" 4.807115487892588e-07
# time 49 is done ", an example is:" 3.7560093346655776e-07
# time 50 is done ", an example is:" 2.934734482096246e-07
# time 51 is done ", an example is:" 2.293036232003942e-07
# time 52 is done ", an example is:" 1.7916495664849208e-07
# time 53 is done ", an example is:" 1.3998942449688911e-07
# time 54 is done ", an example is:" 1.0937985450709675e-07
# time 55 is done ", an example is:" 8.546327023850608e-08
# time 56 is done ", an example is:" 6.677618102912675e-08
# time 57 is done ", an example is:" 5.2175153086864157e-08
# time 58 is done ", an example is:" 4.076672865949149e-08
# time 59 is done ", an example is:" 3.185282793083388e-08
# time 60 is done ", an example is:" 2.4888006322498768e-08
# time 61 is done ", an example is:" 1.9446089183361437e-08
# time 62 is done ", an example is:" 1.519407888395108e-08
# time 63 is done ", an example is:" 1.1871798655249677e-08
# time 64 is done ", an example is:" 9.275955115128909e-09
# time 65 is done ", an example is:" 7.247709543634073e-09
# time 66 is done ", an example is:" 5.662952329288373e-09
# time 67 is done ", an example is:" 4.424712152228949e-09
# time 68 is done ", an example is:" 3.457221398051047e-09
# time 69 is done ", an example is:" 2.7012780901003453e-09
# time 70 is done ", an example is:" 2.1106267844572812e-09
# time 71 is done ", an example is:" 1.6491250587336026e-09
# time 72 is done ", an example is:" 1.2885335021195488e-09
# time 73 is done ", an example is:" 1.0067875422237194e-09
# time 74 is done ", an example is:" 7.866471363193739e-10
# time 75 is done ", an example is:" 6.146417819152816e-10
# time 76 is done ", an example is:" 4.802465092268449e-10
# time 77 is done ", an example is:" 3.752376187549089e-10
# time 78 is done ", an example is:" 2.9318952821100197e-10
# time 79 is done ", an example is:" 2.290818229555569e-10
# time 80 is done ", an example is:" 1.7899164095336317e-10
# time 81 is done ", an example is:" 1.3985400337812592e-10
# time 82 is done ", an example is:" 1.0927404120453232e-10
# time 83 is done ", an example is:" 8.538059148577304e-11
# time 84 is done ", an example is:" 6.671158764293139e-11
# time 85 is done ", an example is:" 5.2124676103160184e-11
# time 86 is done ", an example is:" 4.072729306581202e-11
# time 87 is done ", an example is:" 3.182201377405214e-11
# time 88 is done ", an example is:" 2.486393209377713e-11
# time 89 is done ", an example is:" 1.942727749504325e-11
# time 90 is done ", an example is:" 1.5179382056862423e-11
# time 91 is done ", an example is:" 1.1860313946232548e-11
# time 92 is done ", an example is:" 9.266982146927116e-12
# time 93 is done ", an example is:" 7.240698492172459e-12
# time 94 is done ", an example is:" 5.657474488884873e-12
# time 95 is done ", an example is:" 4.420432336144087e-12
# time 96 is done ", an example is:" 3.453877158235419e-12
# time 97 is done ", an example is:" 2.698665292968916e-12
# time 98 is done ", an example is:" 2.108585224827597e-12
# time 99 is done ", an example is:" 1.6475296604409606e-12
# time 100 is done ", an example is:" 1.28728700875963e-12
# time 101 is done ", an example is:" 1.0058135964732817e-12
# time 102 is done ", an example is:" 7.858861673405715e-13
# time 103 is done ", an example is:" 6.140472787359574e-13
# time 104 is done ", an example is:" 4.797819585199148e-13
# time 105 is done ", an example is:" 3.74874610520326e-13
# time 106 is done ", an example is:" 2.9290594472444753e-13
# time 107 is done ", an example is:" 2.2886022504192693e-13
# time 108 is done ", an example is:" 1.7881848074757095e-13
# time 109 is done ", an example is:" 1.3971872161837318e-13
# time 110 is done ", an example is:" 1.0916835062888333e-13
# time 111 is done ", an example is:" 8.529799316956549e-14
# time 112 is done ", an example is:" 6.664705273122865e-14
# time 113 is done ", an example is:" 5.207425744953309e-14
# time 114 is done ", an example is:" 4.0687895083322753e-14
# time 115 is done ", an example is:" 3.179123021150414e-14
# time 116 is done ", an example is:" 2.4839881535140482e-14
# time 117 is done ", an example is:" 1.9408484354713727e-14
# time 118 is done ", an example is:" 1.5164696823039177e-14
# time 119 is done ", an example is:" 1.184884066134529e-14
# time 120 is done ", an example is:" 9.258017597446773e-15
# time 121 is done ", an example is:" 7.233694403836668e-15
# time 122 is done ", an example is:" 5.652002252857927e-15
# time 123 is done ", an example is:" 4.416156195341959e-15
# time 124 is done ", an example is:" 3.450535882614978e-15
# time 125 is done ", an example is:" 2.696054625617129e-15
# time 126 is done ", an example is:" 2.1065453170747905e-15
# time 127 is done ", an example is:" 1.6459360001379536e-15
# time 128 is done ", an example is:" 1.28604175936585e-15
# time 129 is done ", an example is:" 1.0048405851628152e-15
# time 130 is done ", an example is:" 7.851259561174437e-16
# time 131 is done ", an example is:" 6.134532888348824e-16
# time 132 is done ", an example is:" 4.79317839521961e-16
# time 133 is done ", an example is:" 3.7451199126868346e-16
# time 134 is done ", an example is:" 2.926225929335914e-16
# time 135 is done ", an example is:" 2.2863883582874484e-16
# time 136 is done ", an example is:" 1.7864550867880774e-16
# time 137 is done ", an example is:" 1.3958355199477122e-16
# time 138 is done ", an example is:" 1.0906273806115713e-16
# time 139 is done ", an example is:" 8.521548496072287e-17
# time 140 is done ", an example is:" 6.658257991847588e-17
# time 141 is done ", an example is:" 5.202388680890982e-17
# time 142 is done ", an example is:" 4.0648535421027536e-17
# time 143 is done ", an example is:" 3.1760479739145254e-17
# time 144 is done ", an example is:" 2.4815850164870583e-17
# time 145 is done ", an example is:" 1.9389710782645232e-17
# time 146 is done ", an example is:" 1.5150027985867966e-17
# time 147 is done ", an example is:" 1.1837379736468678e-17
# time 148 is done ", an example is:" 9.249062943799413e-18
# time 149 is done ", an example is:" 7.226697335974641e-18
# time 150 is done ", an example is:" 5.646534211814592e-18
# time 151 is done ", an example is:" 4.411884429517943e-18
# time 152 is done ", an example is:" 3.4471980682226223e-18
# time 153 is done ", an example is:" 2.693446692236233e-18
# time 154 is done ", an example is:" 2.1045077445785846e-18
# time 155 is done ", an example is:" 1.644343861092885e-18
# time 156 is done ", an example is:" 1.284797710330253e-18
# time 157 is done ", an example is:" 1.003868666141039e-18
# time 158 is done ", an example is:" 7.843664678303189e-19
# time 159 is done ", an example is:" 6.128598219005516e-19
# time 160 is done ", an example is:" 4.788541845227e-19
# time 161 is done ", an example is:" 3.741497401339202e-19
# time 162 is done ", an example is:" 2.923395096008944e-19
# time 163 is done ", an example is:" 2.284176801997872e-19
# time 164 is done ", an example is:" 1.7847270868429146e-19
# time 165 is done ", an example is:" 1.394485245825417e-19
# time 166 is done ", an example is:" 1.0895723841185635e-19
# time 167 is done ", an example is:" 8.513306029009108e-20
# time 168 is done ", an example is:" 6.651818132284921e-20
# time 169 is done ", an example is:" 5.197356411312242e-20
# time 170 is done ", an example is:" 4.060921402059194e-20
# time 171 is done ", an example is:" 3.1729753262261965e-20
# time 172 is done ", an example is:" 2.4791846960307337e-20
# time 173 is done ", an example is:" 1.9370954358858016e-20
# time 174 is done ", an example is:" 1.513537280110597e-20
# time 175 is done ", an example is:" 1.1825929799032143e-20
# time 176 is done ", an example is:" 9.240115544370928e-21
# time 177 is done ", an example is:" 7.219705895577418e-21
# time 178 is done ", an example is:" 5.641072086198312e-21
# time 179 is done ", an example is:" 4.4076161420142525e-21
# time 180 is done ", an example is:" 3.443863486684745e-21
# time 181 is done ", an example is:" 2.6908411508548735e-21
# time 182 is done ", an example is:" 2.1024719836208448e-21
# time 183 is done ", an example is:" 1.6427532315490368e-21
# time 184 is done ", an example is:" 1.2835548973092862e-21
# time 185 is done ", an example is:" 1.0028976247643548e-21
# time 186 is done ", an example is:" 7.83607773168062e-22
# time 187 is done ", an example is:" 6.122670330927644e-22
# time 188 is done ", an example is:" 4.78391001345968e-22
# time 189 is done ", an example is:" 3.7378776763462317e-22
# time 190 is done ", an example is:" 2.9205672914393293e-22
# time 191 is done ", an example is:" 2.281967096831878e-22
# time 192 is done ", an example is:" 1.7830005835938285e-22
# time 193 is done ", an example is:" 1.3931363103382315e-22
# time 194 is done ", an example is:" 1.0885183659847344e-22
# time 195 is done ", an example is:" 8.505070401937957e-23
# time 196 is done ", an example is:" 6.645383198243529e-23
# time 197 is done ", an example is:" 5.1923288631859267e-23
# time 198 is done ", an example is:" 4.0569933064158806e-23
# time 199 is done ", an example is:" 3.169906281176007e-23
# time 200 is done ", an example is:" 2.4767864263502297e-23
# time 201 is done ", an example is:" 1.9352217397746078e-23
# time 202 is done ", an example is:" 1.512073279226074e-23
# time 203 is done ", an example is:" 1.181448973187374e-23
# time 204 is done ", an example is:" 9.23117615997119e-24
# time 205 is done ", an example is:" 7.212722494947618e-24
# time 206 is done ", an example is:" 5.635615601581214e-24
# time 207 is done ", an example is:" 4.403352942044934e-24
# time 208 is done ", an example is:" 3.440532035574132e-24
# time 209 is done ", an example is:" 2.688238185968961e-24
# time 210 is done ", an example is:" 2.1004382039661546e-24
# time 211 is done ", an example is:" 1.6411640751997736e-24
# time 212 is done ", an example is:" 1.2823132215669984e-24
# time 213 is done ", an example is:" 1.0019275025557758e-24
# time 214 is done ", an example is:" 7.828497358194211e-25
# time 215 is done ", an example is:" 6.116747586917072e-25
# time 216 is done ", an example is:" 4.779282239845291e-25
# time 217 is done ", an example is:" 3.7342621749618795e-25
# time 218 is done ", an example is:" 2.917742327289622e-25
# time 219 is done ", an example is:" 2.2797596983582793e-25
# time 220 is done ", an example is:" 1.7812757806397603e-25
# time 221 is done ", an example is:" 1.391788650936112e-25
# time 222 is done ", an example is:" 1.0874654654459268e-25
# time 223 is done ", an example is:" 8.49684361314606e-26
# time 224 is done ", an example is:" 6.638954770726883e-26
# time 225 is done ", an example is:" 5.187305875188403e-26
# time 226 is done ", an example is:" 4.053068723412406e-26
# time 227 is done ", an example is:" 3.166839887625371e-26
# time 228 is done ", an example is:" 2.4743905731971975e-26
# time 229 is done ", an example is:" 1.9333493969049932e-26
# time 230 is done ", an example is:" 1.510610547451115e-26
# time 231 is done ", an example is:" 1.1803060893805197e-26
# time 232 is done ", an example is:" 9.222247745964236e-27
# time 233 is done ", an example is:" 7.205745168152358e-27
# time 234 is done ", an example is:" 5.630163836250526e-27
# time 235 is done ", an example is:" 4.399093237986672e-27
# time 236 is done ", an example is:" 3.437203705074e-27
# time 237 is done ", an example is:" 2.6856378554470636e-27
# time 238 is done ", an example is:" 2.0984060227778514e-27
# time 239 is done ", an example is:" 1.6395765172799196e-27
# time 240 is done ", an example is:" 1.2810729396309965e-27
# time 241 is done ", an example is:" 1.0009581773925338e-27
# time 242 is done ", an example is:" 7.820924170244573e-28
# time 243 is done ", an example is:" 6.110830305829898e-28
# time 244 is done ", an example is:" 4.774658629012922e-28
# time 245 is done ", an example is:" 3.7306498025357597e-28
# time 246 is done ", an example is:" 2.9149197671781154e-28
# time 247 is done ", an example is:" 2.277554437312548e-28
# time 248 is done ", an example is:" 1.7795528889708651e-28
# time 249 is done ", an example is:" 1.3904424567198644e-28
# time 250 is done ", an example is:" 1.086413470510194e-28

# %%
diff_2 = (prediction_2-Z_2).tolist()

# %%
import csv

with open("prediction_2.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(prediction_2)

# %%
import csv

with open("diff_2.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(diff_2)

# %% [markdown]
# ## $\Delta x=\frac{1}{80}$

# %%
x_3 = arange(0, 2 * np.pi, 1/80)
t_3 = arange(0, 2 * np.pi, 1/80)
X_3,T_3 = meshgrid(x_3, t_3) # grid of point
Z_3 = heat_equ_analytical_solu(X_3, T_3) # evaluation of the function on the grid

# %%
padding_3 = []
for z in Z_3:
    p = np.hstack(([0,0,0], z, [0,0,0]))
    padding_3.append(p.tolist())

# %%
model_3 = ResNet(7, 6, 1)
optimizer_3 = optim.Adam(model_3.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
criterion_3 = nn.MSELoss()
model_3.train()
# Out:
# ResNet(
#   (linear1): Linear(in_features=7, out_features=6, bias=True)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=6, out_features=1, bias=True)
#   (relu2): ReLU()
# )

# %%
model_3.load_model("model delta x=1 80")

# %%
prediction_3 = []
prediction_3.append(torch.FloatTensor(Z_3[0]).tolist())
for i in range(len(Z_3)-1):
    prediction_3.append(calc_next_time(Z_3[i], model_3))
    print("time", i, "is done", '", an example is:"', prediction_3[i+1][0])
# Out:
# time 0 is done ", an example is:" 0.03360804542899132
# time 1 is done ", an example is:" 0.029707375913858414
# time 2 is done ", an example is:" 0.02625943534076214
# time 3 is done ", an example is:" 0.02321167290210724
# time 4 is done ", an example is:" 0.02051764354109764
# time 5 is done ", an example is:" 0.018136294558644295
# time 6 is done ", an example is:" 0.016031334176659584
# time 7 is done ", an example is:" 0.01417068112641573
# time 8 is done ", an example is:" 0.012525982223451138
# time 9 is done ", an example is:" 0.011072171851992607
# time 10 is done ", an example is:" 0.009787097573280334
# time 11 is done ", an example is:" 0.008651172742247581
# time 12 is done ", an example is:" 0.00764708686619997
# time 13 is done ", an example is:" 0.006759539246559143
# time 14 is done ", an example is:" 0.005975003819912672
# time 15 is done ", an example is:" 0.005281523335725069
# time 16 is done ", an example is:" 0.004668531473726034
# time 17 is done ", an example is:" 0.004126685671508312
# time 18 is done ", an example is:" 0.0036477278918027878
# time 19 is done ", an example is:" 0.003224359592422843
# time 20 is done ", an example is:" 0.002850129036232829
# time 21 is done ", an example is:" 0.0025193332694470882
# time 22 is done ", an example is:" 0.0022269305773079395
# time 23 is done ", an example is:" 0.001968465279787779
# time 24 is done ", an example is:" 0.00173999834805727
# time 25 is done ", an example is:" 0.0015380479162558913
# time 26 is done ", an example is:" 0.0013595366617664695
# time 27 is done ", an example is:" 0.0012017441913485527
# time 28 is done ", an example is:" 0.0010622654808685184
# time 29 is done ", an example is:" 0.0009389752522110939
# time 30 is done ", an example is:" 0.0008299945620819926
# time 31 is done ", an example is:" 0.0007336623966693878
# time 32 is done ", an example is:" 0.0006485110498033464
# time 33 is done ", an example is:" 0.000573242548853159
# time 34 is done ", an example is:" 0.0005067099700681865
# time 35 is done ", an example is:" 0.0004478994233068079
# time 36 is done ", an example is:" 0.00039591468521393836
# time 37 is done ", an example is:" 0.0003499634622130543
# time 38 is done ", an example is:" 0.0003093454579357058
# time 39 is done ", an example is:" 0.00027344172121956944
# time 40 is done ", an example is:" 0.00024170511460397393
# time 41 is done ", an example is:" 0.00021365199063438922
# time 42 is done ", an example is:" 0.00018885478493757546
# time 43 is done ", an example is:" 0.00016693564248271286
# time 44 is done ", an example is:" 0.00014756050950381905
# time 45 is done ", an example is:" 0.00013043412764091045
# time 46 is done ", an example is:" 0.00011529547191457823
# time 47 is done ", an example is:" 0.00010191387991653755
# time 48 is done ", an example is:" 9.008539927890524e-05
# time 49 is done ", an example is:" 7.962977542774752e-05
# time 50 is done ", an example is:" 7.038766489131376e-05
# time 51 is done ", an example is:" 6.221821968210861e-05
# time 52 is done ", an example is:" 5.4996955441311e-05
# time 53 is done ", an example is:" 4.8613816034048796e-05
# time 54 is done ", an example is:" 4.297153282095678e-05
# time 55 is done ", an example is:" 3.798410398303531e-05
# time 56 is done ", an example is:" 3.3575535780983046e-05
# time 57 is done ", an example is:" 2.9678640203201212e-05
# time 58 is done ", an example is:" 2.623403270263225e-05
# time 59 is done ", an example is:" 2.3189219064079225e-05
# time 60 is done ", an example is:" 2.049779868684709e-05
# time 61 is done ", an example is:" 1.8118751540896483e-05
# time 62 is done ", an example is:" 1.6015825167414732e-05
# time 63 is done ", an example is:" 1.415697352058487e-05
# time 64 is done ", an example is:" 1.2513864021457266e-05
# time 65 is done ", an example is:" 1.1061461918870918e-05
# time 66 is done ", an example is:" 9.777629202289972e-06
# time 67 is done ", an example is:" 8.642803550173994e-06
# time 68 is done ", an example is:" 7.63969001127407e-06
# time 69 is done ", an example is:" 6.753000434400747e-06
# time 70 is done ", an example is:" 5.9692238210118376e-06
# time 71 is done ", an example is:" 5.276414412946906e-06
# time 72 is done ", an example is:" 4.664015705202473e-06
# time 73 is done ", an example is:" 4.122693553654244e-06
# time 74 is done ", an example is:" 3.644199296104489e-06
# time 75 is done ", an example is:" 3.221240604034392e-06
# time 76 is done ", an example is:" 2.8473721158661647e-06
# time 77 is done ", an example is:" 2.5168960746668745e-06
# time 78 is done ", an example is:" 2.2247763808991294e-06
# time 79 is done ", an example is:" 1.966561057997751e-06
# time 80 is done ", an example is:" 1.7383151771355188e-06
# time 81 is done ", an example is:" 1.5365601484518265e-06
# time 82 is done ", an example is:" 1.3582217661678442e-06
# time 83 is done ", an example is:" 1.2005815506199724e-06
# time 84 is done ", an example is:" 1.061237867361342e-06
# time 85 is done ", an example is:" 9.380669325764757e-07
# time 86 is done ", an example is:" 8.291916628877516e-07
# time 87 is done ", an example is:" 7.32952742055204e-07
# time 88 is done ", an example is:" 6.478836667156429e-07
# time 89 is done ", an example is:" 5.726880090151099e-07
# time 90 is done ", an example is:" 5.062198624727898e-07
# time 91 is done ", an example is:" 4.4746619209945493e-07
# time 92 is done ", an example is:" 3.9553171404804743e-07
# time 93 is done ", an example is:" 3.4962491213264e-07
# time 94 is done ", an example is:" 3.0904624281902215e-07
# time 95 is done ", an example is:" 2.731772212882788e-07
# time 96 is done ", an example is:" 2.4147132648977276e-07
# time 97 is done ", an example is:" 2.1344531830891356e-07
# time 98 is done ", an example is:" 1.886721037180905e-07
# time 99 is done ", an example is:" 1.6677415715093957e-07
# time 100 is done ", an example is:" 1.4741775089532894e-07
# time 101 is done ", an example is:" 1.3030793866164458e-07
# time 102 is done ", an example is:" 1.151839441604352e-07
# time 103 is done ", an example is:" 1.0181529574992965e-07
# time 104 is done ", an example is:" 8.999825240607606e-08
# time 105 is done ", an example is:" 7.955274128335077e-08
# time 106 is done ", an example is:" 7.031957238723407e-08
# time 107 is done ", an example is:" 6.21580369397634e-08
# time 108 is done ", an example is:" 5.4943757987757635e-08
# time 109 is done ", an example is:" 4.8566793253712603e-08
# time 110 is done ", an example is:" 4.29299618076584e-08
# time 111 is done ", an example is:" 3.794735903284163e-08
# time 112 is done ", an example is:" 3.354305633251897e-08
# time 113 is done ", an example is:" 2.9649930510800004e-08
# time 114 is done ", an example is:" 2.6208656578319278e-08
# time 115 is done ", an example is:" 2.31667875993935e-08
# time 116 is done ", an example is:" 2.0477969542298524e-08
# time 117 is done ", an example is:" 1.8101221854749383e-08
# time 118 is done ", an example is:" 1.6000331726218064e-08
# time 119 is done ", an example is:" 1.414327766013912e-08
# time 120 is done ", an example is:" 1.2501759627525644e-08
# time 121 is done ", an example is:" 1.1050761195008363e-08
# time 122 is done ", an example is:" 9.768172049007262e-09
# time 123 is done ", an example is:" 8.634443382504742e-09
# time 124 is done ", an example is:" 7.632300125237634e-09
# time 125 is done ", an example is:" 6.746468272922357e-09
# time 126 is done ", an example is:" 5.963449289936307e-09
# time 127 is done ", an example is:" 5.271310499210813e-09
# time 128 is done ", an example is:" 4.6595038938335165e-09
# time 129 is done ", an example is:" 4.1187058208436156e-09
# time 130 is done ", an example is:" 3.640674206550898e-09
# time 131 is done ", an example is:" 3.218124655646193e-09
# time 132 is done ", an example is:" 2.8446180966312795e-09
# time 133 is done ", an example is:" 2.514461527880485e-09
# time 134 is done ", an example is:" 2.2226243068246276e-09
# time 135 is done ", an example is:" 1.9646588800270592e-09
# time 136 is done ", an example is:" 1.7366337257129771e-09
# time 137 is done ", an example is:" 1.5350737347930021e-09
# time 138 is done ", an example is:" 1.3569076973141136e-09
# time 139 is done ", an example is:" 1.1994202298026835e-09
# time 140 is done ", an example is:" 1.0602113631463794e-09
# time 141 is done ", an example is:" 9.371595721674453e-10
# time 142 is done ", an example is:" 8.283895236438354e-10
# time 143 is done ", an example is:" 7.322437101109358e-10
# time 144 is done ", an example is:" 6.472569702431485e-10
# time 145 is done ", an example is:" 5.721340623487947e-10
# time 146 is done ", an example is:" 5.057301799560321e-10
# time 147 is done ", an example is:" 4.470333270223392e-10
# time 148 is done ", an example is:" 3.951491078790781e-10
# time 149 is done ", an example is:" 3.4928668291023257e-10
# time 150 is done ", an example is:" 3.08747249988528e-10
# time 151 is done ", an example is:" 2.7291299775633604e-10
# time 152 is done ", an example is:" 2.412377242411168e-10
# time 153 is done ", an example is:" 2.1323885712742907e-10
# time 154 is done ", an example is:" 1.884895989290314e-10
# time 155 is done ", an example is:" 1.6661283464003418e-10
# time 156 is done ", an example is:" 1.4727517816393032e-10
# time 157 is done ", an example is:" 1.3018189304325745e-10
# time 158 is done ", an example is:" 1.150725209564385e-10
# time 159 is done ", an example is:" 1.0171680858706011e-10
# time 160 is done ", an example is:" 8.991119654355728e-11
# time 161 is done ", an example is:" 7.94757940014712e-11
# time 162 is done ", an example is:" 7.025154763473651e-11
# time 163 is done ", an example is:" 6.209790320843567e-11
# time 164 is done ", an example is:" 5.4890609418878356e-11
# time 165 is done ", an example is:" 4.851981663667182e-11
# time 166 is done ", an example is:" 4.288843238886564e-11
# time 167 is done ", an example is:" 3.7910650313444094e-11
# time 168 is done ", an example is:" 3.351060748335577e-11
# time 169 is done ", an example is:" 2.962124989736026e-11
# time 170 is done ", an example is:" 2.6183303789006906e-11
# time 171 is done ", an example is:" 2.3144377039874264e-11
# time 172 is done ", an example is:" 2.0458159472047655e-11
# time 173 is done ", an example is:" 1.80837133462175e-11
# time 174 is done ", an example is:" 1.5984854065398402e-11
# time 175 is done ", an example is:" 1.412959593077856e-11
# time 176 is done ", an example is:" 1.2489666419146506e-11
# time 177 is done ", an example is:" 1.1040071634660364e-11
# time 178 is done ", an example is:" 9.758721608577048e-12
# time 179 is done ", an example is:" 8.626091160812699e-12
# time 180 is done ", an example is:" 7.624916323334396e-12
# time 181 is done ", an example is:" 6.7399419378944e-12
# time 182 is done ", an example is:" 5.95768096314786e-12
# time 183 is done ", an example is:" 5.266211512006125e-12
# time 184 is done ", an example is:" 4.654996440395243e-12
# time 185 is done ", an example is:" 4.114721584291825e-12
# time 186 is done ", an example is:" 3.637152645036279e-12
# time 187 is done ", an example is:" 3.215011590285144e-12
# time 188 is done ", an example is:" 2.841866065389498e-12
# time 189 is done ", an example is:" 2.5120292131142197e-12
# time 190 is done ", an example is:" 2.2204742385067977e-12
# time 191 is done ", an example is:" 1.962758297904821e-12
# time 192 is done ", an example is:" 1.7349536520980258e-12
# time 193 is done ", an example is:" 1.5335890109907657e-12
# time 194 is done ", an example is:" 1.3555952150731687e-12
# time 195 is done ", an example is:" 1.198260024190545e-12
# time 196 is done ", an example is:" 1.0591857252384429e-12
# time 197 is done ", an example is:" 9.362529198100877e-13
# time 198 is done ", an example is:" 8.275882691817504e-13
# time 199 is done ", an example is:" 7.315353834844163e-13
# time 200 is done ", an example is:" 6.466308608357729e-13
# time 201 is done ", an example is:" 5.715805975227417e-13
# time 202 is done ", an example is:" 5.052409228836763e-13
# time 203 is done ", an example is:" 4.4660089970789685e-13
# time 204 is done ", an example is:" 3.9476687435473223e-13
# time 205 is done ", an example is:" 3.4894881580614656e-13
# time 206 is done ", an example is:" 3.084485791782221e-13
# time 207 is done ", an example is:" 2.726489552792172e-13
# time 208 is done ", an example is:" 2.410044006809914e-13
# time 209 is done ", an example is:" 2.1303256738953308e-13
# time 210 is done ", an example is:" 1.8830726908336537e-13
# time 211 is done ", an example is:" 1.6645167774491376e-13
# time 212 is done ", an example is:" 1.4713271291426355e-13
# time 213 is done ", an example is:" 1.3005597304400346e-13
# time 214 is done ", an example is:" 1.149612089551555e-13
# time 215 is done ", an example is:" 1.0161841393309043e-13
# time 216 is done ", an example is:" 8.98242187553043e-14
# time 217 is done ", an example is:" 7.939891013544406e-14
# time 218 is done ", an example is:" 7.018359824513196e-14
# time 219 is done ", an example is:" 6.203783824544964e-14
# time 220 is done ", an example is:" 5.483750931643827e-14
# time 221 is done ", an example is:" 4.847287325758336e-14
# time 222 is done ", an example is:" 4.2846941408292497e-14
# time 223 is done ", an example is:" 3.787397709364461e-14
# time 224 is done ", an example is:" 3.347819119365117e-14
# time 225 is done ", an example is:" 2.959259695471152e-14
# time 226 is done ", an example is:" 2.615797660941721e-14
# time 227 is done ", an example is:" 2.3121990297891512e-14
# time 228 is done ", an example is:" 2.0438371386489497e-14
# time 229 is done ", an example is:" 1.8066220042320044e-14
# time 230 is done ", an example is:" 1.5969391675457918e-14
# time 231 is done ", an example is:" 1.4115928579836162e-14
# time 232 is done ", an example is:" 1.2477583900729738e-14
# time 233 is done ", an example is:" 1.1029392189051274e-14
# time 234 is done ", an example is:" 9.749283154327111e-15
# time 235 is done ", an example is:" 8.617746239650195e-15
# time 236 is done ", an example is:" 7.61754093641211e-15
# time 237 is done ", an example is:" 6.733421922111701e-15
# time 238 is done ", an example is:" 5.9519175612393616e-15
# time 239 is done ", an example is:" 5.261117300007275e-15
# time 240 is done ", an example is:" 4.650493365914018e-15
# time 241 is done ", an example is:" 4.110741102034002e-15
# time 242 is done ", an example is:" 3.63363370086702e-15
# time 243 is done ", an example is:" 3.2119017139014975e-15
# time 244 is done ", an example is:" 2.8391170081007227e-15
# time 245 is done ", an example is:" 2.509599380520408e-15
# time 246 is done ", an example is:" 2.218326561058046e-15
# time 247 is done ", an example is:" 1.9608596735535503e-15
# time 248 is done ", an example is:" 1.7332753672743575e-15
# time 249 is done ", an example is:" 1.5321053599388164e-15
# time 250 is done ", an example is:" 1.3542839216734584e-15
# time 251 is done ", an example is:" 1.1971008646844252e-15
# time 252 is done ", an example is:" 1.058161203313355e-15
# time 253 is done ", an example is:" 9.353473551921123e-16
# time 254 is done ", an example is:" 8.267876422050609e-16
# time 255 is done ", an example is:" 7.30827756066654e-16
# time 256 is done ", an example is:" 6.460053473330164e-16
# time 257 is done ", an example is:" 5.710276849079602e-16
# time 258 is done ", an example is:" 5.047521742851987e-16
# time 259 is done ", an example is:" 4.461689404333679e-16
# time 260 is done ", an example is:" 3.9438497239804545e-16
# time 261 is done ", an example is:" 3.4861128545864346e-16
# time 262 is done ", an example is:" 3.0815021563420004e-16
# time 263 is done ", an example is:" 2.7238522881823247e-16
# time 264 is done ", an example is:" 2.40771232839403e-16
# time 265 is done ", an example is:" 2.1282649094385057e-16
# time 266 is done ", an example is:" 1.8812510437778385e-16
# time 267 is done ", an example is:" 1.6629065964037692e-16
# time 268 is done ", an example is:" 1.4699037866247724e-16
# time 269 is done ", an example is:" 1.2993016895782017e-16
# time 270 is done ", an example is:" 1.1485000464648843e-16
# time 271 is done ", an example is:" 1.015201148066495e-16
# time 272 is done ", an example is:" 8.973733064497055e-17
# time 273 is done ", an example is:" 7.932210764641326e-17
# time 274 is done ", an example is:" 7.011569992526137e-17
# time 275 is done ", an example is:" 6.197782426707078e-17
# time 276 is done ", an example is:" 5.478446644568509e-17
# time 277 is done ", an example is:" 4.842598532527162e-17
# time 278 is done ", an example is:" 4.280549820376571e-17
# time 279 is done ", an example is:" 3.783733894820892e-17
# time 280 is done ", an example is:" 3.3445807297662844e-17
# time 281 is done ", an example is:" 2.9563971105682143e-17
# time 282 is done ", an example is:" 2.613267206921825e-17
# time 283 is done ", an example is:" 2.3099620793029236e-17
# time 284 is done ", an example is:" 2.0418599387569315e-17
# time 285 is done ", an example is:" 1.8048745130578367e-17
# time 286 is done ", an example is:" 1.5953944970873552e-17
# time 287 is done ", an example is:" 1.4102274699893998e-17
# time 288 is done ", an example is:" 1.2465513396681233e-17
# time 289 is done ", an example is:" 1.101872322012801e-17
# time 290 is done ", an example is:" 9.739852362284276e-18
# time 291 is done ", an example is:" 8.609409966376444e-18
# time 292 is done ", an example is:" 7.610172477689937e-18
# time 293 is done ", an example is:" 6.7269086060155075e-18
# time 294 is done ", an example is:" 5.946160122786919e-18
# time 295 is done ", an example is:" 5.256028034892596e-18
# time 296 is done ", an example is:" 4.645994740843926e-18
# time 297 is done ", an example is:" 4.106764384917039e-18
# time 298 is done ", an example is:" 3.6301189277262206e-18
# time 299 is done ", an example is:" 3.208794689517489e-18
# time 300 is done ", an example is:" 2.8363706807859017e-18
# time 301 is done ", an example is:" 2.5071716153487323e-18
# time 302 is done ", an example is:" 2.2161804359956935e-18
# time 303 is done ", an example is:" 1.9589628342580417e-18
# time 304 is done ", an example is:" 1.7315986978153115e-18
# time 305 is done ", an example is:" 1.5306233806718245e-18
# time 306 is done ", an example is:" 1.352973833019297e-18
# time 307 is done ", an example is:" 1.1959428995079959e-18
# time 308 is done ", an example is:" 1.0571375466258054e-18
# time 309 is done ", an example is:" 9.344425701488507e-19
# time 310 is done ", an example is:" 8.259878181097262e-19
# time 311 is done ", an example is:" 7.301207904397039e-19
# time 312 is done ", an example is:" 6.453803759842856e-19
# time 313 is done ", an example is:" 5.704752941084876e-19
# time 314 is done ", an example is:" 5.042639321694102e-19
# time 315 is done ", an example is:" 4.457373366148919e-19
# time 316 is done ", an example is:" 3.940034965518707e-19
# time 317 is done ", an example is:" 3.482740571577954e-19
# time 318 is done ", an example is:" 3.078521704653783e-19
# time 319 is done ", an example is:" 2.721217420146323e-19
# time 320 is done ", an example is:" 2.405383577155267e-19
# time 321 is done ", an example is:" 2.1262061137625283e-19
# time 322 is done ", an example is:" 1.8794312536680522e-19
# time 323 is done ", an example is:" 1.6612980392711075e-19
# time 324 is done ", an example is:" 1.4684819799910553e-19
# time 325 is done ", an example is:" 1.2980446459487717e-19
# time 326 is done ", an example is:" 1.1473890777617524e-19
# time 327 is done ", an example is:" 1.0142191383718237e-19
# time 328 is done ", an example is:" 8.965052625979045e-20
# time 329 is done ", an example is:" 7.924536963569763e-20
# time 330 is done ", an example is:" 7.004787731888662e-20
# time 331 is done ", an example is:" 6.191787450727237e-20
# time 332 is done ", an example is:" 5.473147151707945e-20
# time 333 is done ", an example is:" 4.837914123415274e-20
# time 334 is done ", an example is:" 4.276409060212647e-20
# time 335 is done ", an example is:" 3.7800738739344075e-20
# time 336 is done ", an example is:" 3.341345031854524e-20
# time 337 is done ", an example is:" 2.9535372344129494e-20
# time 338 is done ", an example is:" 2.6107393714041965e-20
# time 339 is done ", an example is:" 2.3077277649482505e-20
# time 340 is done ", an example is:" 2.0398847438990194e-20
# time 341 is done ", an example is:" 1.8031285273627237e-20
# time 342 is done ", an example is:" 1.593851186151954e-20
# time 343 is done ", an example is:" 1.40886322814698e-20
# time 344 is done ", an example is:" 1.2453456153578719e-20
# time 345 is done ", an example is:" 1.1008063854099573e-20
# time 346 is done ", an example is:" 9.730430083636003e-21
# time 347 is done ", an example is:" 8.601082170463202e-21
# time 348 is done ", an example is:" 7.602810072637378e-21
# time 349 is done ", an example is:" 6.720401825602581e-21
# time 350 is done ", an example is:" 5.9404080703659385e-21
# time 351 is done ", an example is:" 5.25094374017697e-21
# time 352 is done ", an example is:" 4.641500652420054e-21
# time 353 is done ", an example is:" 4.102792008352792e-21
# time 354 is done ", an example is:" 3.626607798057526e-21
# time 355 is done ", an example is:" 3.2056910060772007e-21
# time 356 is done ", an example is:" 2.833627145645088e-21
# time 357 is done ", an example is:" 2.504746313714791e-21
# time 358 is done ", an example is:" 2.2140365551001922e-21
# time 359 is done ", an example is:" 1.9570677279317657e-21
# time 360 is done ", an example is:" 1.729923648996956e-21
# time 361 is done ", an example is:" 1.5291426199388102e-21
# time 362 is done ", an example is:" 1.3516650216483235e-21
# time 363 is done ", an example is:" 1.1947859573665762e-21
# time 364 is done ", an example is:" 1.0561150649547781e-21
# time 365 is done ", an example is:" 9.335386515708185e-22
# time 366 is done ", an example is:" 8.251888460524277e-22
# time 367 is done ", an example is:" 7.294145183487675e-22
# time 368 is done ", an example is:" 6.447561369456597e-22
# time 369 is done ", an example is:" 5.699234535682993e-22
# time 370 is done ", an example is:" 5.037761666227456e-22
# time 371 is done ", an example is:" 4.453061497374498e-22
# time 372 is done ", an example is:" 3.93622330877423e-22
# time 373 is done ", an example is:" 3.4793716180199064e-22
# time 374 is done ", an example is:" 3.0755434969999387e-22
# time 375 is done ", an example is:" 2.718585325782624e-22
# time 376 is done ", an example is:" 2.403056614694579e-22
# time 377 is done ", an example is:" 2.1241494773995347e-22
# time 378 is done ", an example is:" 1.877613278904671e-22
# time 379 is done ", an example is:" 1.6596908955994733e-22
# time 380 is done ", an example is:" 1.467061286181834e-22
# time 381 is done ", an example is:" 1.2967891307778615e-22
# time 382 is done ", an example is:" 1.1462791401182514e-22
# time 383 is done ", an example is:" 1.0132380008882174e-22
# time 384 is done ", an example is:" 8.956380250169795e-23
# time 385 is done ", an example is:" 7.916871729633652e-23
# time 386 is done ", an example is:" 6.998012227030735e-23
# time 387 is done ", an example is:" 6.185797252482837e-23
# time 388 is done ", an example is:" 5.467852418286297e-23
# time 389 is done ", an example is:" 4.833234330419529e-23
# time 390 is done ", an example is:" 4.2722721852732463e-23
# time 391 is done ", an example is:" 3.776417570534113e-23
# time 392 is done ", an example is:" 3.338113198730111e-23
# time 393 is done ", an example is:" 2.9506802578932775e-23
# time 394 is done ", an example is:" 2.6082139663758522e-23
# time 395 is done ", an example is:" 2.3054953782010738e-23
# time 396 is done ", an example is:" 2.037911550339572e-23
# time 397 is done ", an example is:" 1.8013843874557162e-23
# time 398 is done ", an example is:" 1.5923092685291895e-23
# time 399 is done ", an example is:" 1.4075004576803474e-23
# time 400 is done ", an example is:" 1.2441409326166457e-23
# time 401 is done ", an example is:" 1.0997415216377499e-23
# time 402 is done ", an example is:" 9.721017761346366e-24
# time 403 is done ", an example is:" 8.592761284567592e-24
# time 404 is done ", an example is:" 7.595455718055507e-24
# time 405 is done ", an example is:" 6.713900501027405e-24
# time 406 is done ", an example is:" 5.9346617266978264e-24
# time 407 is done ", an example is:" 5.2458642774300265e-24
# time 408 is done ", an example is:" 4.637010781158229e-24
# time 409 is done ", an example is:" 4.098823050345677e-24
# time 410 is done ", an example is:" 3.623099692591241e-24
# time 411 is done ", an example is:" 3.2025896956693547e-24
# time 412 is done ", an example is:" 2.8308859313078135e-24
# time 413 is done ", an example is:" 2.502323392130999e-24
# time 414 is done ", an example is:" 2.2118949807582472e-24
# time 415 is done ", an example is:" 1.9551745958655892e-24
# time 416 is done ", an example is:" 1.728250276224034e-24
# time 417 is done ", an example is:" 1.5276635570174796e-24
# time 418 is done ", an example is:" 1.3503576022381946e-24
# time 419 is done ", an example is:" 1.1936303660705706e-24
# time 420 is done ", an example is:" 1.0550933749088248e-24
# time 421 is done ", an example is:" 9.326355383629725e-25
# time 422 is done ", an example is:" 8.243906580502938e-25
# time 423 is done ", an example is:" 7.287089792989387e-25
# time 424 is done ", an example is:" 6.441324406370257e-25
# time 425 is done ", an example is:" 5.693721912568436e-25
# time 426 is done ", an example is:" 5.032888694922202e-25
# time 427 is done ", an example is:" 4.448753957900279e-25
# time 428 is done ", an example is:" 3.9324158992253126e-25
# time 429 is done ", an example is:" 3.4760056313677233e-25
# time 430 is done ", an example is:" 3.0725686058908894e-25
# time 431 is done ", an example is:" 2.71595540551958e-25
# time 432 is done ", an example is:" 2.4007320112119873e-25
# time 433 is done ", an example is:" 2.1220947530933805e-25
# time 434 is done ", an example is:" 1.8757969710438255e-25
# time 435 is done ", an example is:" 1.658085289528184e-25
# time 436 is done ", an example is:" 1.4656421786614524e-25
# time 437 is done ", an example is:" 1.2955346782499223e-25
# time 438 is done ", an example is:" 1.145170394143811e-25
# time 439 is done ", an example is:" 1.0122578703027262e-25
# time 440 is done ", an example is:" 8.947717063525129e-26
# time 441 is done ", an example is:" 7.909213112978359e-26
# time 442 is done ", an example is:" 6.991242178368703e-26
# time 443 is done ", an example is:" 6.179813688282548e-26
# time 444 is done ", an example is:" 5.462562864328138e-26
# time 445 is done ", an example is:" 4.828559052587504e-26
# time 446 is done ", an example is:" 4.268139631418062e-26
# time 447 is done ", an example is:" 3.7727645652232123e-26
# time 448 is done ", an example is:" 3.334884208620957e-26
# time 449 is done ", an example is:" 2.9478259076887744e-26
# time 450 is done ", an example is:" 2.6056907701185995e-26
# time 451 is done ", an example is:" 2.303265380588174e-26
# time 452 is done ", an example is:" 2.0359401413314036e-26
# time 453 is done ", an example is:" 1.7996417875531072e-26
# time 454 is done ", an example is:" 1.590768984331676e-26
# time 455 is done ", an example is:" 1.4061388628038182e-26
# time 456 is done ", an example is:" 1.2429374852463882e-26
# time 457 is done ", an example is:" 1.0986777827664022e-26
# time 458 is done ", an example is:" 9.711613448509411e-27
# time 459 is done ", an example is:" 8.58444985223316e-27
# time 460 is done ", an example is:" 7.588108514103311e-27
# time 461 is done ", an example is:" 6.707406172810294e-27
# time 462 is done ", an example is:" 5.928921022571674e-27
# time 463 is done ", an example is:" 5.2407893349300255e-27
# time 464 is done ", an example is:" 4.632525191710138e-27
# time 465 is done ", an example is:" 4.094857936531709e-27
# time 466 is done ", an example is:" 3.6195946634113154e-27
# time 467 is done ", an example is:" 3.199491757235122e-27
# time 468 is done ", an example is:" 2.8281476194609805e-27
# time 469 is done ", an example is:" 2.4999029049473086e-27
# time 470 is done ", an example is:" 2.2097553958495494e-27
# time 471 is done ", an example is:" 1.9532833496083844e-27
# time 472 is done ", an example is:" 1.726578669180663e-27
# time 473 is done ", an example is:" 1.5261857547636683e-27
# time 474 is done ", an example is:" 1.3490513333200661e-27
# time 475 is done ", an example is:" 1.1924757325503116e-27
# time 476 is done ", an example is:" 1.054072821549806e-27
# time 477 is done ", an example is:" 9.31733418139954e-28
# time 478 is done ", an example is:" 8.235931258380912e-28
# time 479 is done ", an example is:" 7.280040708355515e-28
# time 480 is done ", an example is:" 6.435093352776544e-28
# time 481 is done ", an example is:" 5.688214349965771e-28
# time 482 is done ", an example is:" 5.02802000950441e-28
# time 483 is done ", an example is:" 4.4444502363279525e-28
# time 484 is done ", an example is:" 3.928611808176949e-28
# time 485 is done ", an example is:" 3.472643560500896e-28
# time 486 is done ", an example is:" 3.0695960158367153e-28
# time 487 is done ", an example is:" 2.7133283465567286e-28
# time 488 is done ", an example is:" 2.3984099117002497e-28
# time 489 is done ", an example is:" 2.120042016069595e-28
# time 490 is done ", an example is:" 1.8739824378503866e-28
# time 491 is done ", an example is:" 1.6564815118115244e-28
# time 492 is done ", an example is:" 1.4642244717774748e-28
# time 493 is done ", an example is:" 1.2942814968203389e-28
# time 494 is done ", an example is:" 1.1440626926474017e-28
# time 495 is done ", an example is:" 1.0112787304078946e-28
# time 496 is done ", an example is:" 8.939061197686849e-29
# time 497 is done ", an example is:" 7.901562134792337e-29
# time 498 is done ", an example is:" 6.984480036111315e-29
# time 499 is done ", an example is:" 6.173836863219283e-29
# time 500 is done ", an example is:" 5.457279581082322e-29
# time 501 is done ", an example is:" 4.823888467842308e-29

# %%
diff_3 = (prediction_3-Z_3).tolist()

# %%
import csv

with open("prediction_3.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(prediction_3)

# %%
import csv

with open("diff_3.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(diff_3)

# %% [markdown]
# ## $\Delta x=\frac{1}{160}$

# %%
x_4 = arange(0, 2 * np.pi, 1/160)
t_4 = arange(0, 2 * np.pi, 1/160)
X_4,T_4 = meshgrid(x_4, t_4) # grid of point
Z_4 = heat_equ_analytical_solu(X_4, T_4) # evaluation of the function on the grid

# %%
padding_4 = []
for z in Z_4:
    p = np.hstack(([0,0,0], z, [0,0,0]))
    padding_4.append(p.tolist())

# %%
model_4 = ResNet(7, 6, 1)
optimizer_4 = optim.Adam(model_4.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
criterion_4 = nn.MSELoss()
model_4.train()
# Out:
# ResNet(
#   (linear1): Linear(in_features=7, out_features=6, bias=True)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=6, out_features=1, bias=True)
#   (relu2): ReLU()
# )

# %%
model_4.load_model("model delta x=1 160")

# %%
prediction_4 = []
prediction_4.append(torch.FloatTensor(Z_4[0]).tolist())
for i in range(len(Z_4)-1):
    prediction_4.append(calc_next_time(Z_4[i], model_4))
    print("time", i, "is done", '", an example is:"', prediction_4[i+1][0])
# Out:
# time 0 is done ", an example is:" 0.01682347245514393
# time 1 is done ", an example is:" 0.015817075967788696
# time 2 is done ", an example is:" 0.014870882034301758
# time 3 is done ", an example is:" 0.013981291092932224
# time 4 is done ", an example is:" 0.01314491592347622
# time 5 is done ", an example is:" 0.012358573265373707
# time 6 is done ", an example is:" 0.011619269847869873
# time 7 is done ", an example is:" 0.010924193076789379
# time 8 is done ", an example is:" 0.010270697996020317
# time 9 is done ", an example is:" 0.00965629331767559
# time 10 is done ", an example is:" 0.009078643284738064
# time 11 is done ", an example is:" 0.008535549975931644
# time 12 is done ", an example is:" 0.008024944923818111
# time 13 is done ", an example is:" 0.007544883992522955
# time 14 is done ", an example is:" 0.007093541324138641
# time 15 is done ", an example is:" 0.006669198628515005
# time 16 is done ", an example is:" 0.006270240526646376
# time 17 is done ", an example is:" 0.0058951484970748425
# time 18 is done ", an example is:" 0.005542494356632233
# time 19 is done ", an example is:" 0.005210936535149813
# time 20 is done ", an example is:" 0.004899212624877691
# time 21 is done ", an example is:" 0.00460613751783967
# time 22 is done ", an example is:" 0.0043305931612849236
# time 23 is done ", an example is:" 0.004071532748639584
# time 24 is done ", an example is:" 0.0038279693108052015
# time 25 is done ", an example is:" 0.0035989764146506786
# time 26 is done ", an example is:" 0.003383681643754244
# time 27 is done ", an example is:" 0.00318126636557281
# time 28 is done ", an example is:" 0.0029909596778452396
# time 29 is done ", an example is:" 0.0028120374772697687
# time 30 is done ", an example is:" 0.0026438182685524225
# time 31 is done ", an example is:" 0.0024856626987457275
# time 32 is done ", an example is:" 0.0023369677364826202
# time 33 is done ", an example is:" 0.002197168068960309
# time 34 is done ", an example is:" 0.002065730979666114
# time 35 is done ", an example is:" 0.0019421569304540753
# time 36 is done ", an example is:" 0.0018259750213474035
# time 37 is done ", an example is:" 0.0017167433397844434
# time 38 is done ", an example is:" 0.001614046050235629
# time 39 is done ", an example is:" 0.001517492113634944
# time 40 is done ", an example is:" 0.0014267141232267022
# time 41 is done ", an example is:" 0.0013413665583357215
# time 42 is done ", an example is:" 0.0012611246202141047
# time 43 is done ", an example is:" 0.0011856829514726996
# time 44 is done ", an example is:" 0.0011147542390972376
# time 45 is done ", an example is:" 0.00104806839954108
# time 46 is done ", an example is:" 0.0009853718802332878
# time 47 is done ", an example is:" 0.0009264259715564549
# time 48 is done ", an example is:" 0.0008710061083547771
# time 49 is done ", an example is:" 0.0008189016953110695
# time 50 is done ", an example is:" 0.0007699141278862953
# time 51 is done ", an example is:" 0.0007238570833578706
# time 52 is done ", an example is:" 0.000680555182043463
# time 53 is done ", an example is:" 0.0006398437544703484
# time 54 is done ", an example is:" 0.0006015676190145314
# time 55 is done ", an example is:" 0.0005655811983160675
# time 56 is done ", an example is:" 0.0005317475297488272
# time 57 is done ", an example is:" 0.0004999378579668701
# time 58 is done ", an example is:" 0.00047003108193166554
# time 59 is done ", an example is:" 0.00044191331835463643
# time 60 is done ", an example is:" 0.0004154776397626847
# time 61 is done ", an example is:" 0.0003906233177985996
# time 62 is done ", an example is:" 0.00036725582322105765
# time 63 is done ", an example is:" 0.0003452861856203526
# time 64 is done ", an example is:" 0.00032463084789924324
# time 65 is done ", an example is:" 0.000305211084196344
# time 66 is done ", an example is:" 0.00028695305809378624
# time 67 is done ", an example is:" 0.0002697872114367783
# time 68 is done ", an example is:" 0.00025364826433360577
# time 69 is done ", an example is:" 0.00023847476404625922
# time 70 is done ", an example is:" 0.0002242089540231973
# time 71 is done ", an example is:" 0.00021079655562061816
# time 72 is done ", an example is:" 0.00019818647706415504
# time 73 is done ", an example is:" 0.00018633076979313046
# time 74 is done ", an example is:" 0.00017518426466267556
# time 75 is done ", an example is:" 0.0001647045573918149
# time 76 is done ", an example is:" 0.00015485177573282272
# time 77 is done ", an example is:" 0.00014558837574440986
# time 78 is done ", an example is:" 0.00013687912723980844
# time 79 is done ", an example is:" 0.000128690866404213
# time 80 is done ", an example is:" 0.00012099245941499248
# time 81 is done ", an example is:" 0.00011375456961104646
# time 82 is done ", an example is:" 0.00010694965021684766
# time 83 is done ", an example is:" 0.00010055180609924719
# time 84 is done ", an example is:" 9.453669190406799e-05
# time 85 is done ", an example is:" 8.888141746865585e-05
# time 86 is done ", an example is:" 8.356443140655756e-05
# time 87 is done ", an example is:" 7.856552110752091e-05
# time 88 is done ", an example is:" 7.38656526664272e-05
# time 89 is done ", an example is:" 6.944693450350314e-05
# time 90 is done ", an example is:" 6.529254460474476e-05
# time 91 is done ", an example is:" 6.138667959021404e-05
# time 92 is done ", an example is:" 5.77144674025476e-05
# time 93 is done ", an example is:" 5.426193092716858e-05
# time 94 is done ", an example is:" 5.1015922508668154e-05
# time 95 is done ", an example is:" 4.7964098484953865e-05
# time 96 is done ", an example is:" 4.509483915171586e-05
# time 97 is done ", an example is:" 4.2397216020617634e-05
# time 98 is done ", an example is:" 3.9860973629402e-05
# time 99 is done ", an example is:" 3.7476445868378505e-05
# time 100 is done ", an example is:" 3.5234570532338694e-05
# time 101 is done ", an example is:" 3.31267983710859e-05
# time 102 is done ", an example is:" 3.11451185552869e-05
# time 103 is done ", an example is:" 2.9281987735885195e-05
# time 104 is done ", an example is:" 2.753030821622815e-05
# time 105 is done ", an example is:" 2.5883417038130574e-05
# time 106 is done ", an example is:" 2.433504596410785e-05
# time 107 is done ", an example is:" 2.287929783051368e-05
# time 108 is done ", an example is:" 2.151063563360367e-05
# time 109 is done ", an example is:" 2.0223844330757856e-05
# time 110 is done ", an example is:" 1.901403629744891e-05
# time 111 is done ", an example is:" 1.7876594938570634e-05
# time 112 is done ", an example is:" 1.68071983353002e-05
# time 113 is done ", an example is:" 1.5801775589352474e-05
# time 114 is done ", an example is:" 1.485649681853829e-05
# time 115 is done ", an example is:" 1.3967765880806837e-05
# time 116 is done ", an example is:" 1.3132199455867521e-05
# time 117 is done ", an example is:" 1.2346617950242944e-05
# time 118 is done ", an example is:" 1.1608030945353676e-05
# time 119 is done ", an example is:" 1.0913626283581834e-05
# time 120 is done ", an example is:" 1.0260760973324068e-05
# time 121 is done ", an example is:" 9.646953003539238e-06
# time 122 is done ", an example is:" 9.069861334864981e-06
# time 123 is done ", an example is:" 8.527293175575323e-06
# time 124 is done ", an example is:" 8.017182153707836e-06
# time 125 is done ", an example is:" 7.537586043326883e-06
# time 126 is done ", an example is:" 7.0866799433133565e-06
# time 127 is done ", an example is:" 6.662747182417661e-06
# time 128 is done ", an example is:" 6.264174771786202e-06
# time 129 is done ", an example is:" 5.889445219509071e-06
# time 130 is done ", an example is:" 5.537132437893888e-06
# time 131 is done ", an example is:" 5.20589583175024e-06
# time 132 is done ", an example is:" 4.894473477179417e-06
# time 133 is done ", an example is:" 4.601681666827062e-06
# time 134 is done ", an example is:" 4.326403995946748e-06
# time 135 is done ", an example is:" 4.067594090884086e-06
# time 136 is done ", an example is:" 3.824266059382353e-06
# time 137 is done ", an example is:" 3.595494945329847e-06
# time 138 is done ", an example is:" 3.3804087706812425e-06
# time 139 is done ", an example is:" 3.1781892175786197e-06
# time 140 is done ", an example is:" 2.9880666261306033e-06
# time 141 is done ", an example is:" 2.8093174933019327e-06
# time 142 is done ", an example is:" 2.641261062308331e-06
# time 143 is done ", an example is:" 2.4832584131218027e-06
# time 144 is done ", an example is:" 2.3347072328760987e-06
# time 145 is done ", an example is:" 2.1950424979877425e-06
# time 146 is done ", an example is:" 2.0637328361772234e-06
# time 147 is done ", an example is:" 1.9402782527322415e-06
# time 148 is done ", an example is:" 1.8242087662656559e-06
# time 149 is done ", an example is:" 1.715082703412918e-06
# time 150 is done ", an example is:" 1.6124847661558306e-06
# time 151 is done ", an example is:" 1.5160242128331447e-06
# time 152 is done ", an example is:" 1.4253340623326949e-06
# time 153 is done ", an example is:" 1.340069275101996e-06
# time 154 is done ", an example is:" 1.259904820472002e-06
# time 155 is done ", an example is:" 1.184536017717619e-06
# time 156 is done ", an example is:" 1.113675693886762e-06
# time 157 is done ", an example is:" 1.0470546385477064e-06
# time 158 is done ", an example is:" 9.844187616181443e-07
# time 159 is done ", an example is:" 9.255298323296302e-07
# time 160 is done ", an example is:" 8.70163603394758e-07
# time 161 is done ", an example is:" 8.181095836334862e-07
# time 162 is done ", an example is:" 7.691693895139906e-07
# time 163 is done ", an example is:" 7.23156915682921e-07
# time 164 is done ", an example is:" 6.798969138799293e-07
# time 165 is done ", an example is:" 6.392247655639949e-07
# time 166 is done ", an example is:" 6.009856292621407e-07
# time 167 is done ", an example is:" 5.650340995089209e-07
# time 168 is done ", an example is:" 5.312331836648809e-07
# time 169 is done ", an example is:" 4.994543019165576e-07
# time 170 is done ", an example is:" 4.6957640620348684e-07
# time 171 is done ", an example is:" 4.414858665313659e-07
# time 172 is done ", an example is:" 4.1507570358589874e-07
# time 173 is done ", an example is:" 3.902454750459583e-07
# time 174 is done ", an example is:" 3.669005650408508e-07
# time 175 is done ", an example is:" 3.449521841503156e-07
# time 176 is done ", an example is:" 3.2431680097033677e-07
# time 177 is done ", an example is:" 3.0491582947433926e-07
# time 178 is done ", an example is:" 2.866754584829323e-07
# time 179 is done ", an example is:" 2.69526225338268e-07
# time 180 is done ", an example is:" 2.534029022172035e-07
# time 181 is done ", an example is:" 2.3824408401651453e-07
# time 182 is done ", an example is:" 2.239920746660573e-07
# time 183 is done ", an example is:" 2.105926313333839e-07
# time 184 is done ", an example is:" 1.9799479389348562e-07
# time 185 is done ", an example is:" 1.8615051544657035e-07
# time 186 is done ", an example is:" 1.7501481863746449e-07
# time 187 is done ", an example is:" 1.6454522722142428e-07
# time 188 is done ", an example is:" 1.547019650161019e-07
# time 189 is done ", an example is:" 1.454475295759039e-07
# time 190 is done ", an example is:" 1.3674672061370075e-07
# time 191 is done ", an example is:" 1.2856639841629658e-07
# time 192 is done ", an example is:" 1.2087541279015568e-07
# time 193 is done ", an example is:" 1.1364453200712887e-07
# time 194 is done ", an example is:" 1.0684618700906867e-07
# time 195 is done ", an example is:" 1.0045454246210284e-07
# time 196 is done ", an example is:" 9.444524096124951e-08
# time 197 is done ", an example is:" 8.879543855755401e-08
# time 198 is done ", an example is:" 8.348359870069544e-08
# time 199 is done ", an example is:" 7.848952066069614e-08
# time 200 is done ", an example is:" 7.379419741937454e-08
# time 201 is done ", an example is:" 6.937975882692626e-08
# time 202 is done ", an example is:" 6.522939344222323e-08
# time 203 is done ", an example is:" 6.132729879482213e-08
# time 204 is done ", an example is:" 5.7658635199686614e-08
# time 205 is done ", an example is:" 5.4209440492059e-08
# time 206 is done ", an example is:" 5.096657318404141e-08
# time 207 is done ", an example is:" 4.7917701806454716e-08
# time 208 is done ", an example is:" 4.5051216090996604e-08
# time 209 is done ", an example is:" 4.2356209206673157e-08
# time 210 is done ", an example is:" 3.982241381095264e-08
# time 211 is done ", an example is:" 3.7440194944338145e-08
# time 212 is done ", an example is:" 3.52004825288077e-08
# time 213 is done ", an example is:" 3.309475715695953e-08
# time 214 is done ", an example is:" 3.111499324859324e-08
# time 215 is done ", an example is:" 2.9253660827066597e-08
# time 216 is done ", an example is:" 2.750367755766092e-08
# time 217 is done ", an example is:" 2.585838032587162e-08
# time 218 is done ", an example is:" 2.4311503921126132e-08
# time 219 is done ", an example is:" 2.285716504957236e-08
# time 220 is done ", an example is:" 2.1489825030585052e-08
# time 221 is done ", an example is:" 2.020428269133845e-08
# time 222 is done ", an example is:" 1.899564061602632e-08
# time 223 is done ", an example is:" 1.7859303369505142e-08
# time 224 is done ", an example is:" 1.6790940193800452e-08
# time 225 is done ", an example is:" 1.5786488560820544e-08
# time 226 is done ", an example is:" 1.4842124862468609e-08
# time 227 is done ", an example is:" 1.3954255528858539e-08
# time 228 is done ", an example is:" 1.3119495712032858e-08
# time 229 is done ", an example is:" 1.2334674615033236e-08
# time 230 is done ", an example is:" 1.1596802629298963e-08
# time 231 is done ", an example is:" 1.0903069558310108e-08
# time 232 is done ", an example is:" 1.025083662398174e-08
# time 233 is done ", an example is:" 9.6376213676308e-09
# time 234 is done ", an example is:" 9.061088768191894e-09
# time 235 is done ", an example is:" 8.519044136789944e-09
# time 236 is done ", an example is:" 8.009426899491245e-09
# time 237 is done ", an example is:" 7.530294610091914e-09
# time 238 is done ", an example is:" 7.079824282385516e-09
# time 239 is done ", an example is:" 6.656302620200449e-09
# time 240 is done ", an example is:" 6.258115359258909e-09
# time 241 is done ", an example is:" 5.883748599444516e-09
# time 242 is done ", an example is:" 5.531776370304442e-09
# time 243 is done ", an example is:" 5.200860186960199e-09
# time 244 is done ", an example is:" 4.8897388360558125e-09
# time 245 is done ", an example is:" 4.597229708025452e-09
# time 246 is done ", an example is:" 4.322218583041604e-09
# time 247 is done ", an example is:" 4.063659186925861e-09
# time 248 is done ", an example is:" 3.820566973899986e-09
# time 249 is done ", an example is:" 3.592016906139861e-09
# time 250 is done ", an example is:" 3.37713856879418e-09
# time 251 is done ", an example is:" 3.1751148377168192e-09
# time 252 is done ", an example is:" 2.985176106307108e-09
# time 253 is done ", an example is:" 2.8065996193760157e-09
# time 254 is done ", an example is:" 2.6387059204324714e-09
# time 255 is done ", an example is:" 2.480855965103501e-09
# time 256 is done ", an example is:" 2.3324486786435727e-09
# time 257 is done ", an example is:" 2.192919179577757e-09
# time 258 is done ", an example is:" 2.061736337211073e-09
# time 259 is done ", an example is:" 1.9384012173162546e-09
# time 260 is done ", an example is:" 1.822444195553885e-09
# time 261 is done ", an example is:" 1.713423514182466e-09
# time 262 is done ", an example is:" 1.61092494899151e-09
# time 263 is done ", an example is:" 1.5145575904540465e-09
# time 264 is done ", an example is:" 1.423955287016554e-09
# time 265 is done ", an example is:" 1.3387728703406765e-09
# time 266 is done ", an example is:" 1.2586861553032236e-09
# time 267 is done ", an example is:" 1.1833901636393307e-09
# time 268 is done ", an example is:" 1.112598568830947e-09
# time 269 is done ", an example is:" 1.046041697705391e-09
# time 270 is done ", an example is:" 9.834664194130482e-10
# time 271 is done ", an example is:" 9.246344800928341e-10
# time 272 is done ", an example is:" 8.693218922495305e-10
# time 273 is done ", an example is:" 8.173181575976685e-10
# time 274 is done ", an example is:" 7.684253233719573e-10
# time 275 is done ", an example is:" 7.224573717046212e-10
# time 276 is done ", an example is:" 6.792392204246767e-10
# time 277 is done ", an example is:" 6.386063899910255e-10
# time 278 is done ", an example is:" 6.004042818474886e-10
# time 279 is done ", an example is:" 5.644875122889914e-10
# time 280 is done ", an example is:" 5.307193018389e-10
# time 281 is done ", an example is:" 4.989711421821141e-10
# time 282 is done ", an example is:" 4.69122130031252e-10
# time 283 is done ", an example is:" 4.41058800593197e-10
# time 284 is done ", an example is:" 4.146742116351021e-10
# time 285 is done ", an example is:" 3.898679434843899e-10
# time 286 is done ", an example is:" 3.6654565493954294e-10
# time 287 is done ", an example is:" 3.446185281585912e-10
# time 288 is done ", an example is:" 3.240030743700828e-10
# time 289 is done ", an example is:" 3.046209118284793e-10
# time 290 is done ", an example is:" 2.863981551914918e-10
# time 291 is done ", an example is:" 2.6926549878680817e-10
# time 292 is done ", an example is:" 2.5315777252288285e-10
# time 293 is done ", an example is:" 2.380136088220297e-10
# time 294 is done ", an example is:" 2.237754148648463e-10
# time 295 is done ", an example is:" 2.103889146232163e-10
# time 296 is done ", an example is:" 1.978032321270362e-10
# time 297 is done ", an example is:" 1.8597044737500568e-10
# time 298 is done ", an example is:" 1.7484549919011272e-10
# time 299 is done ", an example is:" 1.643860603195435e-10
# time 300 is done ", an example is:" 1.5455232926786522e-10
# time 301 is done ", an example is:" 1.4530684988578457e-10
# time 302 is done ", an example is:" 1.3661442810342095e-10
# time 303 is done ", an example is:" 1.2844202090800394e-10
# time 304 is done ", an example is:" 1.207584865436928e-10
# time 305 is done ", an example is:" 1.135345914504704e-10
# time 306 is done ", an example is:" 1.0674283679179553e-10
# time 307 is done ", an example is:" 1.0035737518787613e-10
# time 308 is done ", an example is:" 9.435389275447292e-11
# time 309 is done ", an example is:" 8.870954665285424e-11
# time 310 is done ", an example is:" 8.340284018970578e-11
# time 311 is done ", an example is:" 7.841360200044889e-11
# time 312 is done ", an example is:" 7.372281951578685e-11
# time 313 is done ", an example is:" 6.931264590059882e-11
# time 314 is done ", an example is:" 6.516629597053125e-11
# time 315 is done ", an example is:" 6.126797680305884e-11
# time 316 is done ", an example is:" 5.76028634513559e-11
# time 317 is done ", an example is:" 5.415700179978167e-11
# time 318 is done ", an example is:" 5.0917270399963854e-11
# time 319 is done ", an example is:" 4.7871349245776074e-11
# time 320 is done ", an example is:" 4.500763650661099e-11
# time 321 is done ", an example is:" 4.2315231180145574e-11
# time 322 is done ", an example is:" 3.978389145897765e-11
# time 323 is done ", an example is:" 3.740397575002774e-11
# time 324 is done ", an example is:" 3.51664322661982e-11
# time 325 is done ", an example is:" 3.306274004577503e-11
# time 326 is done ", an example is:" 3.108489507464007e-11
# time 327 is done ", an example is:" 2.922536518346064e-11
# time 328 is done ", an example is:" 2.747707270045474e-11
# time 329 is done ", an example is:" 2.5833366695815485e-11
# time 330 is done ", an example is:" 2.4287988287241546e-11
# time 331 is done ", an example is:" 2.2835055027425888e-11
# time 332 is done ", an example is:" 2.1469036617927095e-11
# time 333 is done ", an example is:" 2.0184739296658094e-11
# time 334 is done ", an example is:" 1.8977267673969678e-11
# time 335 is done ", an example is:" 1.784202820209746e-11
# time 336 is done ", an example is:" 1.6774697950139306e-11
# time 337 is done ", an example is:" 1.5771219399884906e-11
# time 338 is done ", an example is:" 1.4827767486069732e-11
# time 339 is done ", an example is:" 1.3940755667907201e-11
# time 340 is done ", an example is:" 1.3106805571427849e-11
# time 341 is done ", an example is:" 1.2322742652670637e-11
# time 342 is done ", an example is:" 1.1585584054618625e-11
# time 343 is done ", an example is:" 1.0892522994687681e-11
# time 344 is done ", an example is:" 1.0240920091109107e-11
# time 345 is done ", an example is:" 9.628298158759208e-12
# time 346 is done ", an example is:" 9.052322259839318e-12
# time 347 is done ", an example is:" 8.510804040684494e-12
# time 348 is done ", an example is:" 8.001678312996585e-12
# time 349 is done ", an example is:" 7.523009992738139e-12
# time 350 is done ", an example is:" 7.072976319216773e-12
# time 351 is done ", an example is:" 6.649863385638222e-12
# time 352 is done ", an example is:" 6.252061368616779e-12
# time 353 is done ", an example is:" 5.8780571556005246e-12
# time 354 is done ", an example is:" 5.526425671253943e-12
# time 355 is done ", an example is:" 5.195829010096187e-12
# time 356 is done ", an example is:" 4.8850090639263044e-12
# time 357 is done ", an example is:" 4.5927831850145484e-12
# time 358 is done ", an example is:" 4.318038114570211e-12
# time 359 is done ", an example is:" 4.059728681699015e-12
# time 360 is done ", an example is:" 3.816871298190083e-12
# time 361 is done ", an example is:" 3.588542223792457e-12
# time 362 is done ", an example is:" 3.373871928363803e-12
# time 363 is done ", an example is:" 3.172043573987371e-12
# time 364 is done ", an example is:" 2.9822884613228684e-12
# time 365 is done ", an example is:" 2.8038851622447236e-12
# time 366 is done ", an example is:" 2.6361536651503537e-12
# time 367 is done ", an example is:" 2.478456459162337e-12
# time 368 is done ", an example is:" 2.3301922457558133e-12
# time 369 is done ", an example is:" 2.190798107162828e-12
# time 370 is done ", an example is:" 2.059741916957125e-12
# time 371 is done ", an example is:" 1.9365262431819685e-12
# time 372 is done ", an example is:" 1.820681192615803e-12
# time 373 is done ", an example is:" 1.71176614549573e-12
# time 374 is done ", an example is:" 1.6093665029109916e-12
# time 375 is done ", an example is:" 1.5130926026007963e-12
# time 376 is done ", an example is:" 1.4225778758106267e-12
# time 377 is done ", an example is:" 1.337477763090067e-12
# time 378 is done ", an example is:" 1.2574686300906301e-12
# time 379 is done ", an example is:" 1.1822454907411961e-12
# time 380 is done ", an example is:" 1.1115223325086632e-12
# time 381 is done ", an example is:" 1.045029839573386e-12
# time 382 is done ", an example is:" 9.825151759887407e-13
# time 383 is done ", an example is:" 9.237400341172153e-13
# time 384 is done ", an example is:" 8.68481014101169e-13
# time 385 is done ", an example is:" 8.165275096685964e-13
# time 386 is done ", an example is:" 7.676820333937795e-13
# time 387 is done ", an example is:" 7.21758481973811e-13
# time 388 is done ", an example is:" 6.785821904387035e-13
# time 389 is done ", an example is:" 6.37988685318891e-13
# time 390 is done ", an example is:" 5.998235220149029e-13
# time 391 is done ", an example is:" 5.639415258558433e-13
# time 392 is done ", an example is:" 5.302059247376534e-13
# time 393 is done ", an example is:" 4.984884575433279e-13
# time 394 is done ", an example is:" 4.686683441508521e-13
# time 395 is done ", an example is:" 4.4063214990792965e-13
# time 396 is done ", an example is:" 4.142730809005707e-13
# time 397 is done ", an example is:" 3.89490821322766e-13
# time 398 is done ", an example is:" 3.661910726905637e-13
# time 399 is done ", an example is:" 3.442851743713088e-13
# time 400 is done ", an example is:" 3.2368966990277415e-13
# time 401 is done ", an example is:" 3.043262256779977e-13
# time 402 is done ", an example is:" 2.861211159492505e-13
# time 403 is done ", an example is:" 2.6900506019771064e-13
# time 404 is done ", an example is:" 2.529128978728118e-13
# time 405 is done ", an example is:" 2.377833715518085e-13
# time 406 is done ", an example is:" 2.2355892365186897e-13
# time 407 is done ", an example is:" 2.1018541182700468e-13
# time 408 is done ", an example is:" 1.9761189212763597e-13
# time 409 is done ", an example is:" 1.8579055123795624e-13
# time 410 is done ", an example is:" 1.7467636766275302e-13
# time 411 is done ", an example is:" 1.6422704396477222e-13
# time 412 is done ", an example is:" 1.5440281702933795e-13
# time 413 is done ", an example is:" 1.451662954340266e-13
# time 414 is done ", an example is:" 1.3648228326581385e-13
# time 415 is done ", an example is:" 1.283177801210747e-13
# time 416 is done ", an example is:" 1.206416693974588e-13
# time 417 is done ", an example is:" 1.1342477250399913e-13
# time 418 is done ", an example is:" 1.0663957781056888e-13
# time 419 is done ", an example is:" 1.0026029485799004e-13
# time 420 is done ", an example is:" 9.426261041254463e-14
# time 421 is done ", an example is:" 8.862372912355615e-14
# time 422 is done ", an example is:" 8.332217023548222e-14
# time 423 is done ", an example is:" 7.833774725912387e-14
# time 424 is done ", an example is:" 7.365151376151693e-14
# time 425 is done ", an example is:" 6.924559395934254e-14
# time 426 is done ", an example is:" 6.510325725782654e-14
# time 427 is done ", an example is:" 6.120870818656851e-14
# time 428 is done ", an example is:" 5.754714060965047e-14
# time 429 is done ", an example is:" 5.4104608976628804e-14
# time 430 is done ", an example is:" 5.0868021546270764e-14
# time 431 is done ", an example is:" 4.7825042130732534e-14
# time 432 is done ", an example is:" 4.496409687182283e-14
# time 433 is done ", an example is:" 4.2274296313971754e-14
# time 434 is done ", an example is:" 3.974540829917647e-14
# time 435 is done ", an example is:" 3.736779359249723e-14
# time 436 is done ", an example is:" 3.5132416046452716e-14
# time 437 is done ", an example is:" 3.3030761285857135e-14
# time 438 is done ", an example is:" 3.1054826543424827e-14
# time 439 is done ", an example is:" 2.919709355471596e-14
# time 440 is done ", an example is:" 2.7450492982752754e-14
# time 441 is done ", an example is:" 2.580837561889926e-14
# time 442 is done ", an example is:" 2.426449374813653e-14
# time 443 is done ", an example is:" 2.281296557367883e-14
# time 444 is done ", an example is:" 2.144827013477596e-14
# time 445 is done ", an example is:" 2.0165211731329458e-14
# time 446 is done ", an example is:" 1.8958909759497246e-14
# time 447 is done ", an example is:" 1.7824768218507522e-14
# time 448 is done ", an example is:" 1.6758472322526974e-14
# time 449 is done ", an example is:" 1.5755963089672358e-14
# time 450 is done ", an example is:" 1.481342548354924e-14
# time 451 is done ", an example is:" 1.3927269778527158e-14
# time 452 is done ", an example is:" 1.3094126477541934e-14
# time 453 is done ", an example is:" 1.23108234422061e-14
# time 454 is done ", an example is:" 1.1574375728413532e-14
# time 455 is done ", an example is:" 1.088198558633945e-14
# time 456 is done ", an example is:" 1.0231013661320208e-14
# time 457 is done ", an example is:" 9.618983229018035e-15
# time 458 is done ", an example is:" 9.043566642893876e-15
# time 459 is done ", an example is:" 8.502570934647291e-15
# time 460 is done ", an example is:" 7.993938661249398e-15
# time 461 is done ", an example is:" 7.515732658349827e-15
# time 462 is done ", an example is:" 7.0661339226943485e-15
# time 463 is done ", an example is:" 6.6434306006965625e-15
# time 464 is done ", an example is:" 6.246014176789633e-15
# time 465 is done ", an example is:" 5.872371003096816e-15
# time 466 is done ", an example is:" 5.521079758332619e-15
# time 467 is done ", an example is:" 5.1908029774733275e-15
# time 468 is done ", an example is:" 4.88028408714169e-15
# time 469 is done ", an example is:" 4.588339782310392e-15
# time 470 is done ", an example is:" 4.313860873335004e-15
# time 471 is done ", an example is:" 4.055801274525667e-15
# time 472 is done ", an example is:" 3.813179274696514e-15
# time 473 is done ", an example is:" 3.585070760902089e-15
# time 474 is done ", an example is:" 3.3706081596461676e-15
# time 475 is done ", an example is:" 3.1689749311675968e-15
# time 476 is done ", an example is:" 2.9794034518579272e-15
# time 477 is done ", an example is:" 2.8011728966790455e-15
# time 478 is done ", an example is:" 2.63360352169078e-15
# time 479 is done ", an example is:" 2.476058781633269e-15
# time 480 is done ", an example is:" 2.3279383419051464e-15
# time 481 is done ", an example is:" 2.188678502080014e-15
# time 482 is done ", an example is:" 2.0577496548076016e-15
# time 483 is done ", an example is:" 1.9346531094402127e-15
# time 484 is done ", an example is:" 1.8189200332415422e-15
# time 485 is done ", an example is:" 1.7101103925954916e-15
# time 486 is done ", an example is:" 1.6078098825117351e-15
# time 487 is done ", an example is:" 1.5116290795927725e-15
# time 488 is done ", an example is:" 1.4212017479680347e-15
# time 489 is done ", an example is:" 1.3361839922609365e-15
# time 490 is done ", an example is:" 1.25625203412739e-15
# time 491 is done ", an example is:" 1.1811017887393307e-15
# time 492 is done ", an example is:" 1.1104471707188237e-15
# time 493 is done ", an example is:" 1.0440189294677604e-15
# time 494 is done ", an example is:" 9.815646491678591e-16
# time 495 is done ", an example is:" 9.22846525319178e-16
# time 496 is done ", an example is:" 8.67640888284083e-16
# time 497 is done ", an example is:" 8.157377268312141e-16
# time 498 is done ", an example is:" 7.669394705256242e-16
# time 499 is done ", an example is:" 7.210603544540687e-16
# time 500 is done ", an example is:" 6.779257310107355e-16
# time 501 is done ", an example is:" 6.373715405016533e-16
# time 502 is done ", an example is:" 5.992432523535074e-16
# time 503 is done ", an example is:" 5.633959709927582e-16
# time 504 is done ", an example is:" 5.296930064775424e-16
# time 505 is done ", an example is:" 4.9800624507458785e-16
# time 506 is done ", an example is:" 4.682149845889108e-16
# time 507 is done ", an example is:" 4.4020590789403647e-16
# time 508 is done ", an example is:" 4.138723417781699e-16
# time 509 is done ", an example is:" 3.8911404518595955e-16
# time 510 is done ", an example is:" 3.6583686511136213e-16
# time 511 is done ", an example is:" 3.43952127792712e-16
# time 512 is done ", an example is:" 3.2337655930338215e-16
# time 513 is done ", an example is:" 3.040318355655312e-16
# time 514 is done ", an example is:" 2.858443441220869e-16
# time 515 is done ", an example is:" 2.687448400296111e-16
# time 516 is done ", an example is:" 2.526682341000633e-16
# time 517 is done ", an example is:" 2.375533546727839e-16
# time 518 is done ", an example is:" 2.233426829166985e-16
# time 519 is done ", an example is:" 2.0998210136741142e-16
# time 520 is done ", an example is:" 1.9742074834341796e-16
# time 521 is done ", an example is:" 1.8561083265764727e-16
# time 522 is done ", an example is:" 1.7450739538944586e-16
# time 523 is done ", an example is:" 1.6406819077056944e-16
# time 524 is done ", an example is:" 1.5425347442694605e-16
# time 525 is done ", an example is:" 1.450258710297781e-16
# time 526 is done ", an example is:" 1.3635026841642394e-16
# time 527 is done ", an example is:" 1.2819365877172025e-16
# time 528 is done ", an example is:" 1.2052496657441464e-16
# time 529 is done ", an example is:" 1.1331504859716563e-16
# time 530 is done ", an example is:" 1.0653641597385688e-16
# time 531 is done ", an example is:" 1.0016330037404612e-16
# time 532 is done ", an example is:" 9.41714290098386e-17
# time 533 is done ", an example is:" 8.853800478355236e-17
# time 534 is done ", an example is:" 8.324156732137533e-17
# time 535 is done ", an example is:" 7.82619731210306e-17
# time 536 is done ", an example is:" 7.358025658543357e-17
# time 537 is done ", an example is:" 6.91786167878021e-17
# time 538 is done ", an example is:" 6.504027850531361e-17
# time 539 is done ", an example is:" 6.114949883654998e-17
# time 540 is done ", an example is:" 5.749147455726898e-17
# time 541 is done ", an example is:" 5.4052272637232753e-17
# time 542 is done ", an example is:" 5.081881038787317e-17
# time 543 is done ", an example is:" 4.777877936167543e-17
# time 544 is done ", an example is:" 4.4920599030063804e-17
# time 545 is done ", an example is:" 4.223340685723424e-17
# time 546 is done ", an example is:" 3.9706962347203325e-17
# time 547 is done ", an example is:" 3.73316470438083e-17
# time 548 is done ", an example is:" 3.509842813476009e-17
# time 549 is done ", an example is:" 3.299880882080654e-17
# time 550 is done ", an example is:" 3.102478199361814e-17
# time 551 is done ", an example is:" 2.9168850088122714e-17
# time 552 is done ", an example is:" 2.7423939055721703e-17
# time 553 is done ", an example is:" 2.578340994481876e-17
# time 554 is done ", an example is:" 2.4241020850511558e-17
# time 555 is done ", an example is:" 2.279089879045097e-17
# time 556 is done ", an example is:" 2.142752316122882e-17
# time 557 is done ", an example is:" 2.0145707540404396e-17
# time 558 is done ", an example is:" 1.8940569908002414e-17
# time 559 is done ", an example is:" 1.7807526029068104e-17
# time 560 is done ", an example is:" 1.6742259675165163e-17
# time 561 is done ", an example is:" 1.5740720970014533e-17
# time 562 is done ", an example is:" 1.479909495663112e-17
# time 563 is done ", an example is:" 1.391379828860134e-17
# time 564 is done ", an example is:" 1.3081460204929044e-17
# time 565 is done ", an example is:" 1.2298914258229378e-17
# time 566 is done ", an example is:" 1.1563180116755313e-17
# time 567 is done ", an example is:" 1.0871458601313969e-17
# time 568 is done ", an example is:" 1.0221117623196203e-17
# time 569 is done ", an example is:" 9.609679776467418e-18
# time 570 is done ", an example is:" 9.034818202064503e-18
# time 571 is done ", an example is:" 8.49434666162848e-18
# time 572 is done ", an example is:" 7.986205475434093e-18
# time 573 is done ", an example is:" 7.508463176751029e-18
# time 574 is done ", an example is:" 7.05929914105106e-18
# time 575 is done ", an example is:" 6.637003999598344e-18
# time 576 is done ", an example is:" 6.2399717812336104e-18
# time 577 is done ", an example is:" 5.866690399797112e-18
# time 578 is done ", an example is:" 5.515738758996482e-18
# time 579 is done ", an example is:" 5.185781375732755e-18
# time 580 is done ", an example is:" 4.875563417016687e-18
# time 581 is done ", an example is:" 4.583901187391714e-18
# time 582 is done ", an example is:" 4.309687505607935e-18
# time 583 is done ", an example is:" 4.051878056142002e-18
# time 584 is done ", an example is:" 3.809490562016507e-18
# time 585 is done ", an example is:" 3.581602716848454e-18
# time 586 is done ", an example is:" 3.3673476353558877e-18
# time 587 is done ", an example is:" 3.1659095106596773e-18
# time 588 is done ", an example is:" 2.9765215463319863e-18
# time 589 is done ", an example is:" 2.7984628544689747e-18
# time 590 is done ", an example is:" 2.6310559741489616e-18
# time 591 is done ", an example is:" 2.473663562709975e-18
# time 592 is done ", an example is:" 2.3256863277982198e-18
# time 593 is done ", an example is:" 2.186561373006854e-18
# time 594 is done ", an example is:" 2.0557590959486907e-18
# time 595 is done ", an example is:" 1.9327815338949727e-18
# time 596 is done ", an example is:" 1.817160502618995e-18
# time 597 is done ", an example is:" 1.708456045432456e-18
# time 598 is done ", an example is:" 1.6062545720290792e-18
# time 599 is done ", an example is:" 1.5101667905330819e-18
# time 600 is done ", an example is:" 1.4198268803185624e-18
# time 601 is done ", an example is:" 1.3348914580337346e-18
# time 602 is done ", an example is:" 1.2550369926615139e-18
# time 603 is done ", an example is:" 1.1799592885316337e-18
# time 604 is done ", an example is:" 1.1093729683327634e-18
# time 605 is done ", an example is:" 1.0430090949682465e-18
# time 606 is done ", an example is:" 9.806151715561013e-19
# time 607 is done ", an example is:" 9.219537972605251e-19
# time 608 is done ", an example is:" 8.668016333161286e-19
# time 609 is done ", an example is:" 8.149486275461115e-19
# time 610 is done ", an example is:" 7.661975490731683e-19
# time 611 is done ", an example is:" 7.203627992473573e-19
# time 612 is done ", an example is:" 6.772699463570065e-19
# time 613 is done ", an example is:" 6.367550018456772e-19
# time 614 is done ", an example is:" 5.9866364483034e-19
# time 615 is done ", an example is:" 5.628509636074332e-19
# time 616 is done ", an example is:" 5.291806284722505e-19
# time 617 is done ", an example is:" 4.975244781286344e-19
# time 618 is done ", an example is:" 4.677621060986702e-19
# time 619 is done ", an example is:" 4.397800852408615e-19
# time 620 is done ", an example is:" 4.1347196775013047e-19
# time 621 is done ", an example is:" 3.887376647723581e-19
# time 622 is done ", an example is:" 3.6548295526589586e-19
# time 623 is done ", an example is:" 3.436193826039888e-19
# time 624 is done ", an example is:" 3.2306371173749877e-19
# time 625 is done ", an example is:" 3.037377482491454e-19
# time 626 is done ", an example is:" 2.8556779551622902e-19
# time 627 is done ", an example is:" 2.684848615057839e-19
# time 628 is done ", an example is:" 2.524238315939656e-19
# time 629 is done ", an example is:" 2.3732357196362766e-19
# time 630 is done ", an example is:" 2.2312661941159176e-19
# time 631 is done ", an example is:" 2.0977897455349469e-19
# time 632 is done ", an example is:" 1.972297787063615e-19
# time 633 is done ", an example is:" 1.8543128803921138e-19
# time 634 is done ", an example is:" 1.7433858922972214e-19
# time 635 is done ", an example is:" 1.6390947021725942e-19
# time 636 is done ", an example is:" 1.5410425218181483e-19
# time 637 is done ", an example is:" 1.448855698241557e-19
# time 638 is done ", an example is:" 1.36218358441128e-19
# time 639 is done ", an example is:" 1.2806966005520034e-19
# time 640 is done ", an example is:" 1.2040837784521955e-19
# time 641 is done ", an example is:" 1.1320543124277557e-19
# time 642 is done ", an example is:" 1.0643337465363782e-19
# time 643 is done ", an example is:" 1.0006641684480085e-19
# time 644 is done ", an example is:" 9.408033693395333e-20
# time 645 is done ", an example is:" 8.845235514250738e-20
# time 646 is done ", an example is:" 8.316104878506759e-20
# time 647 is done ", an example is:" 7.818626179655151e-20
# time 648 is done ", an example is:" 7.350907888279552e-20
# time 649 is done ", an example is:" 6.911169627358412e-20
# time 650 is done ", an example is:" 6.497735709916459e-20
# time 651 is done ", an example is:" 6.109034492789842e-20
# time 652 is done ", an example is:" 5.743586098163914e-20
# time 653 is done ", an example is:" 5.3999988592815414e-20
# time 654 is done ", an example is:" 5.0769654430339774e-20
# time 655 is done ", an example is:" 4.773256064494903e-20
# time 656 is done ", an example is:" 4.487714932628732e-20
# time 657 is done ", an example is:" 4.2192550804117806e-20
# time 658 is done ", an example is:" 3.9668551336580025e-20
# time 659 is done ", an example is:" 3.7295534949053045e-20
# time 660 is done ", an example is:" 3.506448020298121e-20
# time 661 is done ", an example is:" 3.296688587886598e-20
# time 662 is done ", an example is:" 3.099477420744019e-20
# time 663 is done ", an example is:" 2.914063593970551e-20
# time 664 is done ", an example is:" 2.739741095988682e-20
# time 665 is done ", an example is:" 2.575847051397377e-20
# time 666 is done ", an example is:" 2.4217571973280996e-20
# time 667 is done ", an example is:" 2.2768852372099598e-20
# time 668 is done ", an example is:" 2.140679609595447e-20
# time 669 is done ", an example is:" 2.012622034132008e-20
# time 670 is done ", an example is:" 1.892224765063921e-20
# time 671 is done ", an example is:" 1.779029944997441e-20
# time 672 is done ", an example is:" 1.672606535285245e-20
# time 673 is done ", an example is:" 1.5725495082328663e-20
# time 674 is done ", an example is:" 1.478477908394133e-20
# time 675 is done ", an example is:" 1.390033883218888e-20
# time 676 is done ", an example is:" 1.3068806635690713e-20
# time 677 is done ", an example is:" 1.2287016751457966e-20
# time 678 is done ", an example is:" 1.1551994883577143e-20
# time 679 is done ", an example is:" 1.0860942027338774e-20
# time 680 is done ", an example is:" 1.0211230430269585e-20
# time 681 is done ", an example is:" 9.600383397293316e-21
# time 682 is done ", an example is:" 9.026078521904998e-21
# time 683 is done ", an example is:" 8.486129106918906e-21
# time 684 is done ", an example is:" 7.97848012550073e-21
# time 685 is done ", an example is:" 7.501199335438334e-21
# time 686 is done ", an example is:" 7.052470008999656e-21
# time 687 is done ", an example is:" 6.630583662790603e-21
# time 688 is done ", an example is:" 6.2339360187872214e-21
# time 689 is done ", an example is:" 5.86101529132897e-21
# time 690 is done ", an example is:" 5.510402994912292e-21
# time 691 is done ", an example is:" 5.180765058461375e-21
# time 692 is done ", an example is:" 4.870846574669968e-21
# time 693 is done ", an example is:" 4.579467761033546e-21
# time 694 is done ", an example is:" 4.3055191130879076e-21
# time 695 is done ", an example is:" 4.0479589810284764e-21
# time 696 is done ", an example is:" 3.805805491774629e-21
# time 697 is done ", an example is:" 3.5781381645568295e-21
# time 698 is done ", an example is:" 3.364090438826137e-21
# time 699 is done ", an example is:" 3.1628468469767185e-21
# time 700 is done ", an example is:" 2.9736422065522845e-21
# time 701 is done ", an example is:" 2.795755965691119e-21
# time 702 is done ", an example is:" 2.628510789487337e-21
# time 703 is done ", an example is:" 2.4712709444037524e-21
# time 704 is done ", an example is:" 2.3234368456652988e-21
# time 705 is done ", an example is:" 2.1844464708977735e-21
# time 706 is done ", an example is:" 2.053770311418043e-21
# time 707 is done ", an example is:" 1.9309119780792192e-21
# time 708 is done ", an example is:" 1.8154027486640812e-21
# time 709 is done ", an example is:" 1.706803385420602e-21
# time 710 is done ", an example is:" 1.6047007019392884e-21
# time 711 is done ", an example is:" 1.5087058465918519e-21
# time 712 is done ", an example is:" 1.418453393763445e-21
# time 713 is done ", an example is:" 1.3336001321623113e-21
# time 714 is done ", an example is:" 1.2538227424132807e-21
# time 715 is done ", an example is:" 1.178817797057769e-21
# time 716 is done ", an example is:" 1.1082997410698606e-21
# time 717 is done ", an example is:" 1.0420001850369376e-21
# time 718 is done ", an example is:" 9.796666934693292e-22
# time 719 is done ", an example is:" 9.210618760325492e-22
# time 720 is done ", an example is:" 8.65963084624708e-22
# time 721 is done ", an example is:" 8.141602424313014e-22
# time 722 is done ", an example is:" 7.654562983090927e-22
# time 723 is done ", an example is:" 7.1966601509576145e-22
# time 724 is done ", an example is:" 6.766148084066513e-22
# time 725 is done ", an example is:" 6.361390495573578e-22
# time 726 is done ", an example is:" 5.980846014378879e-22
# time 727 is done ", an example is:" 5.6230646510297485e-22
# time 728 is done ", an example is:" 5.286687292849798e-22
# time 729 is done ", an example is:" 4.970432072422481e-22
# time 730 is done ", an example is:" 4.673095882204025e-22
# time 731 is done ", an example is:" 4.393546296587769e-22
# time 732 is done ", an example is:" 4.1307198048557294e-22
# time 733 is done ", an example is:" 3.8836162575978307e-22
# time 734 is done ", an example is:" 3.651294070437601e-22
# time 735 is done ", an example is:" 3.432869971596683e-22
# time 736 is done ", an example is:" 3.227512438572101e-22
# time 737 is done ", an example is:" 3.0344389213458754e-22
# time 738 is done ", an example is:" 2.852915589949534e-22
# time 739 is done ", an example is:" 2.682251528447848e-22
# time 740 is done ", an example is:" 2.521796463019425e-22
# time 741 is done ", an example is:" 2.370940004650242e-22
# time 742 is done ", an example is:" 2.2291078626012973e-22
# time 743 is done ", an example is:" 2.0957604560134203e-22
# time 744 is done ", an example is:" 1.9703900108991382e-22
# time 745 is done ", an example is:" 1.8525190455297388e-22
# time 746 is done ", an example is:" 1.7416996131288014e-22
# time 747 is done ", an example is:" 1.637509262904362e-22
# time 748 is done ", an example is:" 1.5395517973553825e-22
# time 749 is done ", an example is:" 1.4474541168281295e-22
# time 750 is done ", an example is:" 1.3608659670806848e-22
# time 751 is done ", an example is:" 1.2794575411457938e-22
# time 752 is done ", an example is:" 1.2029191006776303e-22
# time 753 is done ", an example is:" 1.1309592089033696e-22
# time 754 is done ", an example is:" 1.0633040995344638e-22
# time 755 is done ", an example is:" 9.996961621537038e-23
# time 756 is done ", an example is:" 9.398933742353679e-23
# time 757 is done ", an example is:" 8.836679127500283e-23
# time 758 is done ", an example is:" 8.308060279468062e-23
# time 759 is done ", an example is:" 7.811064025226893e-23
# time 760 is done ", an example is:" 7.343797729692969e-23
# time 761 is done ", an example is:" 6.904484247019008e-23
# time 762 is done ", an example is:" 6.491450560997218e-23
# time 763 is done ", an example is:" 6.103125891793123e-23
# time 764 is done ", an example is:" 5.738030336348528e-23
# time 765 is done ", an example is:" 5.394774868381519e-23
# time 766 is done ", an example is:" 5.0720543964105e-23
# time 767 is done ", an example is:" 4.768638612967687e-23
# time 768 is done ", an example is:" 4.483373887865286e-23
# time 769 is done ", an example is:" 4.215173486320263e-23
# time 770 is done ", an example is:" 3.963017884498712e-23
# time 771 is done ", an example is:" 3.7259459342737104e-23
# time 772 is done ", an example is:" 3.50305580985841e-23
# time 773 is done ", an example is:" 3.293499959096242e-23
# time 774 is done ", an example is:" 3.0964791081180354e-23
# time 775 is done ", an example is:" 2.911244470152555e-23
# time 776 is done ", an example is:" 2.737090803550533e-23
# time 777 is done ", an example is:" 2.573355149607222e-23
# time 778 is done ", an example is:" 2.419414623751859e-23
# time 779 is done ", an example is:" 2.2746827867875032e-23
# time 780 is done ", an example is:" 2.13860901380231e-23
# time 781 is done ", an example is:" 2.0106750231815493e-23
# time 782 is done ", an example is:" 1.8903944032910618e-23
# time 783 is done ", an example is:" 1.777308983717095e-23
# time 784 is done ", an example is:" 1.6709886774941228e-23
# time 785 is done ", an example is:" 1.5710283256612233e-23
# time 786 is done ", an example is:" 1.4770478550342612e-23
# time 787 is done ", an example is:" 1.3886892805344472e-23
# time 788 is done ", an example is:" 1.305616389643976e-23
# time 789 is done ", an example is:" 1.2275130857981256e-23
# time 790 is done ", an example is:" 1.1540820473217183e-23
# time 791 is done ", an example is:" 1.085043623023853e-23
# time 792 is done ", an example is:" 1.0201352799952725e-23
# time 793 is done ", an example is:" 9.591097103421897e-24
# time 794 is done ", an example is:" 9.017347523001982e-24
# time 795 is done ", an example is:" 8.477920491707328e-24
# time 796 is done ", an example is:" 7.970762604601645e-24
# time 797 is done ", an example is:" 7.493943519049856e-24
# time 798 is done ", an example is:" 7.045647277248144e-24
# time 799 is done ", an example is:" 6.62416993964123e-24
# time 800 is done ", an example is:" 6.227905385426086e-24
# time 801 is done ", an example is:" 5.85534570698238e-24
# time 802 is done ", an example is:" 5.505072532402525e-24
# time 803 is done ", an example is:" 5.175753475617604e-24
# time 804 is done ", an example is:" 4.866135036649219e-24
# time 805 is done ", an example is:" 4.575037474013614e-24
# time 806 is done ", an example is:" 4.301354410291215e-24
# time 807 is done ", an example is:" 4.044042576934867e-24
# time 808 is done ", an example is:" 3.802123786422097e-24
# time 809 is done ", an example is:" 3.574676649215607e-24
# time 810 is done ", an example is:" 3.360836179332821e-24
# time 811 is done ", an example is:" 3.1597874834586467e-24
# time 812 is done ", an example is:" 2.9707655637302455e-24
# time 813 is done ", an example is:" 2.793051570647735e-24
# time 814 is done ", an example is:" 2.6259682671239826e-24
# time 815 is done ", an example is:" 2.468880028484607e-24
# time 816 is done ", an example is:" 2.32118889816345e-24
# time 817 is done ", an example is:" 2.182333207195995e-24
# time 818 is done ", an example is:" 2.0517836299148382e-24
# time 819 is done ", an example is:" 1.9290439728105958e-24
# time 820 is done ", an example is:" 1.813646638581698e-24
# time 821 is done ", an example is:" 1.7051524289191628e-24
# time 822 is done ", an example is:" 1.6031484737467204e-24
# time 823 is done ", an example is:" 1.5072464562837757e-24
# time 824 is done ", an example is:" 1.4170813311464377e-24
# time 825 is done ", an example is:" 1.3323101410561614e-24
# time 826 is done ", an example is:" 1.2526099460798722e-24
# time 827 is done ", an example is:" 1.1776776264147387e-24
# time 828 is done ", an example is:" 1.1072277130206842e-24
# time 829 is done ", an example is:" 1.0409921904051597e-24

# %%
diff_4 = (prediction_4-Z_4).tolist()

# %%
import csv

with open("prediction_4.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(prediction_4)

# %%
import csv

with open("diff_4.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(diff_4)
